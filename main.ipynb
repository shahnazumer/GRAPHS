# %% [markdown]
# In This notebook we have used LLMs in combination with Neo4j, a graph database, to perform ***Retrieval Augmented Generation (RAG)***.
#
# ### ***Why use RAG?***
# If you want to use LLMs to generate answers based on your own content or knowledge base, instead of providing large context when prompting the model, you can fetch the relevant information in a database and use this information to generate a response.
#
# This allows you to:
#
#  - Reduce hallucinations
#  - Provide relevant, up to date information to your users
#  - Leverage your own content/knowledge base
#
# ### ***Why use a graph database?***
# If you have data where relationships between data points are important and you might want to leverage that, then it might be worth considering graph databases instead of traditional relational databases.
#
# ## Graph databases are good to address the following:
#
#  - Navigating deep hierarchies
#  - Finding hidden connections between items
#  - Discovering relationships between items
#
# ### Use cases
#
# Graph databases are particularly relevant for finding relationships or analysing correlation between data points,
# Recommendation chatbot, tool to analyse.

# %% [markdown]
# LLM Graph Generation

# %%
# importing the requisite libraries and modules, setting a foundation for interfacing with the dataset preparation
from langchain.docstore.document import Document

from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_community.graphs import Neo4jGraph
from langchain.chains import GraphCypherQAChain
from neo4j import GraphDatabase
import openai
import json
from dotenv import load_dotenv

# %%
# Load environment variabless
load_dotenv()
# Out:
# True

# %%
#loads environment variables, safeguarding sensitive credentials for the OpenAI API and Neo4j database.

import os

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Next, we need to define Neo4j credentials

NEO4J_USER = os.getenv("NEO4J_USER")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_CONNECTION_URL = os.getenv("NEO4J_CONNECTION_URL")

# %%
# Neo4j configuration & constraints

graph = Neo4jGraph(NEO4J_CONNECTION_URL, NEO4J_USER, NEO4J_PASSWORD)

# %%
## Data Ingestion and upload multiple files

from langchain_community.document_loaders import TextLoader
loader=TextLoader("Data/Profiles.txt")
profile_documents=loader.load()

# %%
loader=TextLoader("Data/Projects.txt")
project_documents=loader.load()

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("Data/slackmsg.txt")
slackmsg=loader.load()


documents = profile_documents + project_documents + slackmsg

# %%
documents[:3]
# Out:
# [Document(page_content='Full Name: Sarah Johnson \nSkills: Machine Learning, Data Analytics, Azure, Python \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nFull Name: David Patel \nSkills: AWS, Cloud Computing, DevOps, Data Warehousing \nProjects:\n\nFull Name: Amanda Rodriguez \nSkills: Data Security, Compliance, Healthcare Regulations, Azure \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nFull Name: Jason Mitchell \nSkills: Data Analytics, Machine Learning, Azure, Data Warehousing \nProjects: GammaTech Smart Logistics Platform on Azure\n\nFull Name: Emily Turner \nSkills: IoT, Real-time Data Management, Azure, Python \nProjects: GammaTech Smart Logistics Platform on Azure\n\nFull Name: Michael Clark \nSkills: Data Engineering, Data Warehousing, AWS, Python \nProjects: AlphaCorp AWS-Powered Supply Chain Optimization Platform\n\nFull Name: Jessica White \nSkills: Data Privacy, Security Compliance, Azure Key Vault, Healthcare Regulations \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nFull Name: Daniel Brown \nSkills: Cloud Architecture, DevOps, AWS Lambda, Azure Functions \nProjects: GammaTech Smart Logistics Platform on Azure\n\nFull Name: Olivia Martinez \nSkills: Real-time Monitoring, Azure Monitoring, Data Analytics \nProjects: AlphaCorp AWS-Powered Supply Chain Optimization Platform\n\nFull Name: William Lee \nSkills: Predictive Modeling, Machine Learning, AWS SageMaker, Azure Machine Learning \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nElla Smith Skills: Machine Learning, Data Analytics, Azure, Python Projects:\n\n - AlphaCorp AWS-Powered Sales Analytics Dashboard\n - DeltaEdu AI-Powered Student Performance Analytics on AWS\n\nLucas Taylor Skills: AWS, Cloud Computing, DevOps, Data Warehousing Projects:\n\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n - BetaHealth Telemedicine Platform on Microsoft Azure\n\nLiam Thompson Skills: Data Security, Compliance, Healthcare Regulations, Azure Projects:\n\n - DeltaEdu AI-Powered Student Performance Analytics on AWS\n - DeltaEdu Virtual Classroom Platform on AWS\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nSophia Anderson Skills: Data Analytics, Machine Learning, Azure, Data Warehousing Projects:\n\n - BetaHealth Telemedicine Platform on Microsoft Azure\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nAiden Lewis Skills: IoT, Real-time Data Management, Azure, Python Projects:\n\n - BetaHealth Telemedicine Platform on Microsoft Azure\n\n\nEmma Martinez Skills: Data Engineering, Data Warehousing, AWS, Python Projects:\n\n - AlphaCorp AWS-Powered Sales Analytics Dashboard\n - DeltaEdu Virtual Classroom Platform on AWS\n\n Noah Wilson Skills: Data Privacy, Security Compliance, Azure Key Vault, Healthcare Regulations Projects:\n\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n \n Ava Jackson Skills: Cloud Architecture, DevOps, AWS Lambda, Azure Functions Projects:\n\n - BetaHealth Telemedicine Platform on Microsoft Azure\n - EpsilonFinance Mobile-First Digital Wallet on Google Cloud\n\nBenjamin White Skills: Real-time Monitoring, Azure Monitoring, Data Analytics Projects:\n\n - DeltaEdu AI-Powered Student Performance Analytics on AWS\n - DeltaEdu Virtual Classroom Platform on AWS\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nIsabella Harris Skills: Predictive Modeling, Machine Learning, AWS SageMaker, Azure Machine Learning Projects:\n\n - AlphaCorp AWS-Powered Sales Analytics Dashboard\n - DeltaEdu Virtual Classroom Platform on AWS\n', metadata={'source': 'Data/Profiles.txt'}),
#  Document(page_content="Brief: AlphaCorp AWS-Powered Sales Analytics Dashboard\nCustomer Need: AlphaCorp is keen on understanding its sales trends, customer behaviors, and product performance in real-time. They need an intuitive dashboard hosted on the AWS platform for their sales teams and executives to make informed decisions.\nDelivered Solution: We have built a Sales Analytics Dashboard hosted on AWS, providing real-time insights into sales metrics, customer segmentation, and product performance. The dashboard, with its drill-down capabilities, helps AlphaCorp's team to track KPIs and adapt their strategies promptly.\nTechnologies Involved: Our solution is powered by AWS services, including Quicksight for data visualization, Redshift for data warehousing, Lambda for serverless computations, and S3 for data storage.\nTimeline & Customer Experience: The project was completed in four months, with AlphaCorp's sales and IT teams being closely involved. Post-launch, AlphaCorp's teams have been able to identify sales opportunities 20% faster and address market shifts promptly.\n\nBrief: AlphaCorp AWS-Powered Customer Support Chatbot\nCustomer Need: AlphaCorp is experiencing a surge in customer support demands due to their expanding customer base. They require an efficient solution to handle customer inquiries and provide instant support, ensuring a seamless customer experience.\nDelivered Solution: We have developed a cutting-edge Customer Support Chatbot hosted on the AWS platform, empowered by natural language processing and machine learning algorithms. This chatbot can swiftly respond to common customer queries, offer detailed product information, and assist in resolving typical issues. It seamlessly integrates with AlphaCorp's existing CRM system, hosted on AWS infrastructure, to streamline support operations.\nTechnologies Involved: Our solution leverages AWS services such as Lambda for serverless computing to handle chatbot functions, Lex for natural language understanding and interaction, S3 for data storage, DynamoDB for chat history and user profiles, CloudWatch for monitoring and logging, and API Gateway for API management.\nTimeline & Customer Experience: The project spanned five months, with active participation from AlphaCorp's customer support team for chatbot training. Post-implementation, AlphaCorp reported a remarkable 30% reduction in response times for customer inquiries, contributing to heightened customer satisfaction.\n\nBrief: AlphaCorp AWS-Powered Supply Chain Optimization Platform\nCustomer Need: AlphaCorp grapples with managing a complex supply chain, encompassing multiple suppliers and distribution centers. They require a robust platform hosted on the AWS platform to optimize supply chain operations, reduce costs, and ensure punctual deliveries.\nDelivered Solution: We have devised a Supply Chain Optimization Platform hosted on AWS, powered by advanced algorithms and data analytics, tailored to meet AlphaCorp's unique requirements. The platform offers real-time visibility into inventory levels, order fulfillment, and transportation logistics, utilizing predictive analytics to identify potential disruptions and optimize procurement strategies.\nTechnologies Involved: Our solution utilizes AWS services, including EC2 instances for platform hosting, SageMaker for machine learning and predictive analytics, RDS for database management, S3 for data storage and retrieval, Lambda for serverless event-driven functions, and CloudWatch for monitoring and logging.\nTimeline & Customer Experience: The project unfolded over a six-month period, characterized by ongoing collaboration with AlphaCorp's supply chain and procurement teams. Since its implementation, AlphaCorp has achieved a notable 15% reduction in supply chain operating costs and a remarkable 20% improvement in on-time deliveries, significantly enhancing their competitive edge in the market.\n\nBrief: BetaHealth AI-Driven Patient Care Enhancement Platform  ...
#  Document(page_content='\n        "id": "kcojvioa",\n        "type": "message",\n        "user": "Sarah Johnson",\n        "text": "I\'ve been working on BetaHealth\'s Azure-based data analytics platform. It\'s a game-changer for patient care. Collaborating with healthcare professionals has been invaluable."\n    \n    \n        "id": "asjdnifkjasd",\n        "type": "message",\n        "user": "David Patel",\n        "text": "AlphaCorp\'s AWS-powered supply chain optimization project has been both challenging and rewarding. AWS services like EC2 and SageMaker have made a real difference."\n    \n    \n        "id": "asdffjasd",\n        "type": "message",\n        "user": "Amanda Rodriguez",\n        "text": "Data security and compliance have been my top priorities in BetaHealth\'s Azure project. It\'s vital to protect patient information while advancing healthcare."\n    \n    \n        "id": "lklklkhg",\n        "type": "message",\n        "user": "Jason Mitchell",\n        "text": "Working on GammaTech\'s Azure-based smart logistics platform has been fascinating. Real-time logistics management is transforming the transportation industry."\n    \n    \n        "id": "jtthh",\n        "type": "message",\n        "user": "Emily Turner",\n        "text": "The IoT integration in GammaTech\'s Azure project is exciting. Azure technologies have truly revolutionized how we manage logistics operations."\n    \n    \n        "id": "heaas",\n        "type": "message",\n        "user": "Olivia Martinez",\n        "text": "Monitoring efficiency improvements in AlphaCorp\'s AWS project is fascinating. AWS services like EC2 and SageMaker are making a real impact."\n    \n    \n        "id": "jsssa",\n        "type": "message",\n        "user": "William Lee",\n        "text": "Applying predictive modeling in BetaHealth\'s Azure project is exciting. Collaborating with healthcare professionals and Azure\'s ML capabilities are key."\n    \n    \n        "id": "ppaa",\n        "type": "message",\n        "user": "Sarah Johnson",\n        "text": "David, I noticed you worked on the AlphaCorp AWS project too. How was your experience with it?"\n    \n    \n        "id": "gfdd",\n        "type": "message",\n        "user": "David Patel",\n        "text": "Sarah, it was quite challenging but rewarding. We\'ve seen significant cost reductions and improved deliveries in their supply chain."\n    \n    \n        "id": "lopyyy",\n        "type": "message",\n        "user": "Emily Turner",\n        "text": "Jason, I\'m curious about your experience with real-time logistics in the GammaTech project. Any key takeaways?"\n    \n    \n        "id": "fgtttta",\n        "type": "message",\n        "user": "Jason Mitchell",\n        "text": "Emily, real-time logistics is all about efficiency. Azure IoT Hub and Functions have made our logistics operations highly responsive."\n    \n    \n        "id": "pldfpaks",\n        "type": "message",\n        "user": "Olivia Martinez",\n        "text": "Michael, how\'s the monitoring going in the AlphaCorp AWS project? Any interesting insights you\'ve gained?"\n    \n    \n        "id": "ytthf",\n        "type": "message",\n        "user": "Michael Clark",\n        "text": "The data engineering challenge in AlphaCorp\'s AWS project has been rewarding. AWS services like EC2 and SageMaker have driven cost reductions."\n    \n    \n        "id": "agaer",\n        "type": "message",\n        "user": "Jessica White",\n        "text": "Ensuring data privacy in BetaHealth\'s Azure project is crucial. Collaborating with healthcare professionals and implementing Azure Key Vault is a must."\n    \n    \n        "id": "bbtgg",\n        "type": "message",\n        "user": "Daniel Brown",\n        "text": "Optimizing logistics operations in GammaTech\'s Azure project is a great journey. Azure IoT Hub and Functions are pivotal for efficiency."\n    \n    \n        "id": "gapaa",\n        "type": "message",\n        "user": "Michael Cl ...

# %% [markdown]
# The uploades files which are chunked into smaller text pieces using TokenTextSplitter from LangChain. This splitter ensures that each chunk is maximized to 512 tokens with an overlap of 24 tokens, adhering to context window limits for embedding models and making sure that the continuity of the context is not lost.

# %%
from langchain.text_splitter import TokenTextSplitter
text_splitter=TokenTextSplitter(chunk_size=512,chunk_overlap=24)
docs=text_splitter.split_documents(documents)
docs[:5]
# Out:
# [Document(page_content='Full Name: Sarah Johnson \nSkills: Machine Learning, Data Analytics, Azure, Python \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nFull Name: David Patel \nSkills: AWS, Cloud Computing, DevOps, Data Warehousing \nProjects:\n\nFull Name: Amanda Rodriguez \nSkills: Data Security, Compliance, Healthcare Regulations, Azure \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nFull Name: Jason Mitchell \nSkills: Data Analytics, Machine Learning, Azure, Data Warehousing \nProjects: GammaTech Smart Logistics Platform on Azure\n\nFull Name: Emily Turner \nSkills: IoT, Real-time Data Management, Azure, Python \nProjects: GammaTech Smart Logistics Platform on Azure\n\nFull Name: Michael Clark \nSkills: Data Engineering, Data Warehousing, AWS, Python \nProjects: AlphaCorp AWS-Powered Supply Chain Optimization Platform\n\nFull Name: Jessica White \nSkills: Data Privacy, Security Compliance, Azure Key Vault, Healthcare Regulations \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nFull Name: Daniel Brown \nSkills: Cloud Architecture, DevOps, AWS Lambda, Azure Functions \nProjects: GammaTech Smart Logistics Platform on Azure\n\nFull Name: Olivia Martinez \nSkills: Real-time Monitoring, Azure Monitoring, Data Analytics \nProjects: AlphaCorp AWS-Powered Supply Chain Optimization Platform\n\nFull Name: William Lee \nSkills: Predictive Modeling, Machine Learning, AWS SageMaker, Azure Machine Learning \nProjects: BetaHealth Secure Healthcare Data Analytics Platform on Azure\n\nElla Smith Skills: Machine Learning, Data Analytics, Azure, Python Projects:\n\n - AlphaCorp AWS-Powered Sales Analytics Dashboard\n - DeltaEdu AI-Powered Student Performance Analytics on AWS\n\nLucas Taylor Skills: AWS, Cloud Computing, DevOps, Data Warehousing Projects:\n\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n - BetaHealth Telemedicine Platform on Microsoft Azure\n\nLiam Thompson Skills: Data Security, Compliance, Healthcare Regulations, Azure Projects:\n\n - DeltaEdu AI-Powered Student Performance Analytics on AWS\n - DeltaEdu Virtual Classroom Platform on AWS\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nSophia Anderson Skills', metadata={'source': 'Data/Profiles.txt'}),
#  Document(page_content='room Platform on AWS\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nSophia Anderson Skills: Data Analytics, Machine Learning, Azure, Data Warehousing Projects:\n\n - BetaHealth Telemedicine Platform on Microsoft Azure\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nAiden Lewis Skills: IoT, Real-time Data Management, Azure, Python Projects:\n\n - BetaHealth Telemedicine Platform on Microsoft Azure\n\n\nEmma Martinez Skills: Data Engineering, Data Warehousing, AWS, Python Projects:\n\n - AlphaCorp AWS-Powered Sales Analytics Dashboard\n - DeltaEdu Virtual Classroom Platform on AWS\n\n Noah Wilson Skills: Data Privacy, Security Compliance, Azure Key Vault, Healthcare Regulations Projects:\n\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n \n Ava Jackson Skills: Cloud Architecture, DevOps, AWS Lambda, Azure Functions Projects:\n\n - BetaHealth Telemedicine Platform on Microsoft Azure\n - EpsilonFinance Mobile-First Digital Wallet on Google Cloud\n\nBenjamin White Skills: Real-time Monitoring, Azure Monitoring, Data Analytics Projects:\n\n - DeltaEdu AI-Powered Student Performance Analytics on AWS\n - DeltaEdu Virtual Classroom Platform on AWS\n - GammaTech IoT-Driven Manufacturing Monitoring System on Azure\n\nIsabella Harris Skills: Predictive Modeling, Machine Learning, AWS SageMaker, Azure Machine Learning Projects:\n\n - AlphaCorp AWS-Powered Sales Analytics Dashboard\n - DeltaEdu Virtual Classroom Platform on AWS\n', metadata={'source': 'Data/Profiles.txt'}),
#  Document(page_content="Brief: AlphaCorp AWS-Powered Sales Analytics Dashboard\nCustomer Need: AlphaCorp is keen on understanding its sales trends, customer behaviors, and product performance in real-time. They need an intuitive dashboard hosted on the AWS platform for their sales teams and executives to make informed decisions.\nDelivered Solution: We have built a Sales Analytics Dashboard hosted on AWS, providing real-time insights into sales metrics, customer segmentation, and product performance. The dashboard, with its drill-down capabilities, helps AlphaCorp's team to track KPIs and adapt their strategies promptly.\nTechnologies Involved: Our solution is powered by AWS services, including Quicksight for data visualization, Redshift for data warehousing, Lambda for serverless computations, and S3 for data storage.\nTimeline & Customer Experience: The project was completed in four months, with AlphaCorp's sales and IT teams being closely involved. Post-launch, AlphaCorp's teams have been able to identify sales opportunities 20% faster and address market shifts promptly.\n\nBrief: AlphaCorp AWS-Powered Customer Support Chatbot\nCustomer Need: AlphaCorp is experiencing a surge in customer support demands due to their expanding customer base. They require an efficient solution to handle customer inquiries and provide instant support, ensuring a seamless customer experience.\nDelivered Solution: We have developed a cutting-edge Customer Support Chatbot hosted on the AWS platform, empowered by natural language processing and machine learning algorithms. This chatbot can swiftly respond to common customer queries, offer detailed product information, and assist in resolving typical issues. It seamlessly integrates with AlphaCorp's existing CRM system, hosted on AWS infrastructure, to streamline support operations.\nTechnologies Involved: Our solution leverages AWS services such as Lambda for serverless computing to handle chatbot functions, Lex for natural language understanding and interaction, S3 for data storage, DynamoDB for chat history and user profiles, CloudWatch for monitoring and logging, and API Gateway for API management.\nTimeline & Customer Experience: The project spanned five months, with active participation from AlphaCorp's customer support team for chatbot training. Post-implementation, AlphaCorp reported a remarkable 30% reduction in response times for customer inquiries, contributing to heightened customer satisfaction.\n\nBrief: AlphaCorp AWS-Powered Supply Chain Optimization Platform\nCustomer Need: AlphaCorp grapples with managing a complex supply chain, encompassing multiple suppliers and distribution centers. They require a robust platform hosted on the", metadata={'source': 'Data/Projects.txt'}),
#  Document(page_content="les with managing a complex supply chain, encompassing multiple suppliers and distribution centers. They require a robust platform hosted on the AWS platform to optimize supply chain operations, reduce costs, and ensure punctual deliveries.\nDelivered Solution: We have devised a Supply Chain Optimization Platform hosted on AWS, powered by advanced algorithms and data analytics, tailored to meet AlphaCorp's unique requirements. The platform offers real-time visibility into inventory levels, order fulfillment, and transportation logistics, utilizing predictive analytics to identify potential disruptions and optimize procurement strategies.\nTechnologies Involved: Our solution utilizes AWS services, including EC2 instances for platform hosting, SageMaker for machine learning and predictive analytics, RDS for database management, S3 for data storage and retrieval, Lambda for serverless event-driven functions, and CloudWatch for monitoring and logging.\nTimeline & Customer Experience: The project unfolded over a six-month period, characterized by ongoing collaboration with AlphaCorp's supply chain and procurement teams. Since its implementation, AlphaCorp has achieved a notable 15% reduction in supply chain operating costs and a remarkable 20% improvement in on-time deliveries, significantly enhancing their competitive edge in the market.\n\nBrief: BetaHealth AI-Driven Patient Care Enhancement Platform on Azure\nCustomer Need: BetaHealth, a prominent healthcare provider, is committed to elevating patient care through AI and data analytics. They seek a cutting-edge platform hosted on Microsoft Azure to offer personalized patient insights, optimize resource allocation, and enhance overall healthcare outcomes.\nDelivered Solution: We have developed an AI-Driven Patient Care Enhancement Platform hosted on Microsoft Azure, harnessing the potential of machine learning and data analytics. This platform provides real-time patient monitoring, predictive analytics for disease management, and intelligent resource allocation for healthcare facilities. It enables BetaHealth to deliver more personalized care while maximizing operational efficiency.\nTechnologies Involved: Our solution leverages Microsoft Azure services, such as Azure Virtual Machines for scalable hosting, Azure Machine Learning for building and deploying machine learning models, Azure Functions for serverless functions, and Azure SQL Database for data warehousing. Additionally, we utilize Azure IoT for real-time patient data collection and Azure Cognitive Services for natural language processing of medical records.\nTimeline & Customer Experience: The project spanned over nine months, involving close collaboration with BetaHealth's healthcare professionals. Since implementation, BetaHealth has observed a 25% reduction in patient readmission rates and a 30% improvement in resource allocation efficiency, leading to increased patient satisfaction and improved healthcare outcomes.", metadata={'source': 'Data/Projects.txt'}),
#  Document(page_content=" patient readmission rates and a 30% improvement in resource allocation efficiency, leading to increased patient satisfaction and improved healthcare outcomes.\n\nBrief: BetaHealth Secure Healthcare Data Analytics Platform on Azure\nCustomer Need: BetaHealth, a leading healthcare provider, is dedicated to advancing patient care through data analytics and AI. They require an advanced platform hosted on Microsoft Azure to provide secure, data-driven patient insights, optimize resource allocation, and improve healthcare outcomes while ensuring data privacy and compliance.\nDelivered Solution: We've created a Secure Healthcare Data Analytics Platform hosted on Microsoft Azure, leveraging cutting-edge technologies for data analysis and AI. This platform enables real-time patient monitoring, predictive analytics for disease management, and secure data handling to protect patient information. BetaHealth can now deliver personalized care while ensuring strict data privacy and compliance with healthcare regulations.\nTechnologies Involved: Our solution leverages Microsoft Azure services, such as Azure Databricks for data analytics, Azure Machine Learning for predictive modeling, Azure Key Vault for data encryption, and Azure Active Directory for access control. We also use Azure Synapse Analytics for data warehousing and Azure Logic Apps for workflow automation.\nTimeline & Customer Experience: The project unfolded over nine months, involving close collaboration with BetaHealth's healthcare professionals and data security experts. Since implementation, BetaHealth has seen a 25% reduction in patient readmission rates and a 30% improvement in resource allocation efficiency, all while maintaining the highest standards of data security and compliance.\n\nBrief: BetaHealth Telemedicine Platform on Microsoft Azure Customer Need: With the evolving healthcare landscape, BetaHealth aims to provide remote consultations and care to its patients. They envision a Telemedicine Platform on Microsoft Azure to make healthcare more accessible.\nDelivered Solution: We've crafted a Telemedicine Platform on Microsoft Azure, facilitating virtual doctor-patient interactions, secure data exchange, and remote monitoring. This platform ensures that BetaHealth can offer continuous care, irrespective of geographical constraints.\nTechnologies Involved: Our solution integrates Microsoft Azure services such as Azure Communication Services for video consultations, Azure Blob Storage for storing patient documents, Azure SQL Database for patient data, and Azure Security Center for ensuring data privacy and compliance.\nTimeline & Customer Experience: The project took seven months to complete, with BetaHealth's medical and IT professionals actively participating. Since its inception, the platform has enabled a 40% increase in remote consultations, greatly enhancing patient accessibility.\n\nBrief: DeltaEdu AI-Powered Student Performance Analytics", metadata={'source': 'Data/Projects.txt'})]

# %% [markdown]
# The chunked documents are instantiated into the Neo4j vector index as nodes. It uses the core functionalities of Neo4j graph database and OpenAI embeddings to construct this vector index

# %%
# Instantiate Neo4j vector from documents
neo4j_vector = Neo4jVector.from_documents(
    docs,
    OpenAIEmbeddings(),
    url=os.environ["NEO4J_CONNECTION_URL"],
    username=os.environ["NEO4J_USER"],
    password=os.environ["NEO4J_PASSWORD"]
)

# %% [markdown]
# Building Knowledge Graph

# %%
#initialize model

from langchain_openai import ChatOpenAI
llm=ChatOpenAI(temperature=0.5, model_name="gpt-3.5-turbo")

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer = LLMGraphTransformer(llm=llm)

# %%
graph_documents= llm_transformer.convert_to_graph_documents(docs)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Amanda Rodriguez', type='Person'), Node(id='Jason Mitchell', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Michael Clark', type='Person'), Node(id='Jessica White', type='Person'), Node(id='Daniel Brown', type='Person'), Node(id='Olivia Martinez', type='Person'), Node(id='William Lee', type='Person'), Node(id='Ella Smith', type='Person'), Node(id='Lucas Taylor', type='Person'), Node(id='Liam Thompson', type='Person')], relationships=[Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Aws', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Cloud Computing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Devops', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Data Security', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Compliance', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Healthcare Regulations', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Iot', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Real-Time Data Management', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Engineering', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Warehousi ...
#  GraphDocument(nodes=[Node(id='Platform On Aws', type='Platform'), Node(id='Gammatech Iot-Driven Manufacturing Monitoring System', type='System'), Node(id='Azure', type='Cloud service'), Node(id='Sophia Anderson', type='Person'), Node(id='Data Analytics', type='Skill'), Node(id='Machine Learning', type='Skill'), Node(id='Data Warehousing', type='Skill'), Node(id='Betahealth Telemedicine Platform', type='Project'), Node(id='Aiden Lewis', type='Person'), Node(id='Iot', type='Skill'), Node(id='Real-Time Data Management', type='Skill'), Node(id='Python', type='Skill'), Node(id='Emma Martinez', type='Person'), Node(id='Data Engineering', type='Skill'), Node(id='Aws', type='Cloud service'), Node(id='Alphacorp Aws-Powered Sales Analytics Dashboard', type='Project'), Node(id='Deltaedu Virtual Classroom Platform', type='Project'), Node(id='Noah Wilson', type='Person'), Node(id='Data Privacy', type='Skill'), Node(id='Security Compliance', type='Skill'), Node(id='Azure Key Vault', type='Skill'), Node(id='Healthcare Regulations', type='Skill'), Node(id='Ava Jackson', type='Person'), Node(id='Cloud Architecture', type='Skill'), Node(id='Devops', type='Skill'), Node(id='Aws Lambda', type='Skill'), Node(id='Azure Functions', type='Skill'), Node(id='Benjamin White', type='Person'), Node(id='Real-Time Monitoring', type='Skill'), Node(id='Azure Monitoring', type='Skill'), Node(id='Isabella Harris', type='Person'), Node(id='Predictive Modeling', type='Skill'), Node(id='Aws Sagemaker', type='Skill'), Node(id='Azure Machine Learning', type='Skill'), Node(id='Epsilonfinance Mobile-First Digital Wallet', type='Project'), Node(id='Google Cloud', type='Cloud service')], relationships=[Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Azure', type='Cloud service'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Betahealth Telemedicine Platform', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Iot', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Real-Time Data Management', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Azure', type='Cloud service'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Betahealth Telemedicine Platform', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Data Engineering', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Aws', type='Cloud service'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Alphacorp Aws-Powered Sales Analytics Dashboard', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Deltaedu Virtual Classroom Platform', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Noah Wilson', type='Person'), target=Node(id='Data Privacy', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Noah Wilson', type='Perso ...
#  GraphDocument(nodes=[Node(id='Alphacorp', type='Company'), Node(id='Sales Analytics Dashboard', type='Dashboard'), Node(id='Aws', type='Platform'), Node(id='Sales Teams', type='Team'), Node(id='Executives', type='Team'), Node(id='Quicksight', type='Service'), Node(id='Redshift', type='Service'), Node(id='Lambda', type='Service'), Node(id='S3', type='Service'), Node(id='Customer Support Chatbot', type='Chatbot'), Node(id='Natural Language Processing', type='Algorithm'), Node(id='Machine Learning', type='Algorithm'), Node(id='Crm System', type='System'), Node(id='Dynamodb', type='Database'), Node(id='Cloudwatch', type='Monitoring tool'), Node(id='Api Gateway', type='Api management'), Node(id='Customer Support Team', type='Team'), Node(id='Supply Chain Optimization Platform', type='Platform'), Node(id='Suppliers', type='Entity'), Node(id='Distribution Centers', type='Entity')], relationships=[Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Sales Analytics Dashboard', type='Dashboard'), type='UTILIZES'), Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Customer Support Chatbot', type='Chatbot'), type='UTILIZES'), Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Supply Chain Optimization Platform', type='Platform'), type='UTILIZES'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Quicksight', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Redshift', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Lambda', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='S3', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Lambda', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Lex', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='S3', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Dynamodb', type='Database'), type='USES_DATABASE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Cloudwatch', type='Monitoring tool'), type='USES_TOOL'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Api Gateway', type='Api management'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Crm System', type='System'), type='INTEGRATES_WITH'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Suppliers', type='Entity'), type='MANAGES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Distribution Centers', type='Entity'), type='MANAGES')], source=Document(page_content="Brief: AlphaCorp AWS-Powered Sales Analytics Dashboard\nCustomer Need: AlphaCorp is keen on understanding its sales trends, customer behaviors, and product performance in real-time. They need an intuitive dashboard hosted on the AWS platform for their sales teams and executives to make informed decisions.\nDelivered Solution: We have built a Sales Analytics Dashboard hosted on AWS, providing real-time insights into sales metrics, customer segmentation, and product performance. The dashboard, with its drill-down capabilities, ...
#  GraphDocument(nodes=[Node(id='Supply Chain Optimization Platform', type='Platform'), Node(id='Aws', type='Cloud service provider'), Node(id='Alphacorp', type='Company'), Node(id='Technologies', type='Technology'), Node(id='Ec2', type='Service'), Node(id='Sagemaker', type='Service'), Node(id='Rds', type='Service'), Node(id='S3', type='Service'), Node(id='Lambda', type='Service'), Node(id='Cloudwatch', type='Service'), Node(id='Supply Chain', type='Process'), Node(id='Inventory Levels', type='Data'), Node(id='Order Fulfillment', type='Process'), Node(id='Transportation Logistics', type='Process'), Node(id='Predictive Analytics', type='Technology'), Node(id='Disruptions', type='Event'), Node(id='Procurement Strategies', type='Process'), Node(id='Reduction In Costs', type='Outcome'), Node(id='On-Time Deliveries', type='Outcome'), Node(id='Competitive Edge', type='Outcome'), Node(id='Betahealth Ai-Driven Patient Care Enhancement Platform', type='Platform'), Node(id='Azure', type='Cloud service provider'), Node(id='Betahealth', type='Company'), Node(id='Healthcare Provider', type='Role'), Node(id='Ai And Data Analytics', type='Technology'), Node(id='Personalized Patient Insights', type='Data'), Node(id='Resource Allocation', type='Process'), Node(id='Healthcare Outcomes', type='Outcome'), Node(id='Patient Monitoring', type='Process'), Node(id='Disease Management', type='Process'), Node(id='Resource Allocation For Healthcare Facilities', type='Process'), Node(id='Personalized Care', type='Outcome'), Node(id='Operational Efficiency', type='Outcome'), Node(id='Machine Learning', type='Technology'), Node(id='Data Analytics', type='Technology'), Node(id='Azure Virtual Machines', type='Service'), Node(id='Azure Machine Learning', type='Service'), Node(id='Azure Functions', type='Service'), Node(id='Azure Sql Database', type='Service'), Node(id='Azure Iot', type='Service'), Node(id='Azure Cognitive Services', type='Service'), Node(id='Patient Data', type='Data'), Node(id='Medical Records', type='Data'), Node(id='Natural Language Processing', type='Process'), Node(id='Readmission Rates', type='Outcome'), Node(id='Patient Satisfaction', type='Outcome')], relationships=[Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Supply Chain Optimization Platform', type='Platform'), type='UTILIZES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Aws', type='Cloud service provider'), type='HOSTED_ON'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Technologies', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Ec2', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Sagemaker', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Rds', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='S3', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Lambda', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Cloudwatch', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Supply Chain', type='Process'), type='OPTIMIZES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Reduction In Costs', type='Outcome'), type='ACHIEVES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='On-Time Deliveries', type='Outcome'), type='ACHIEVES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Competitive Edge', type='Outcome'), type='ENH ...
#  GraphDocument(nodes=[Node(id='Betahealth', type='Healthcare provider'), Node(id='Microsoft Azure', type='Cloud service'), Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), Node(id='Data Insights', type='Insights'), Node(id='Resource Allocation', type='Resource allocation'), Node(id='Patient Satisfaction', type='Satisfaction'), Node(id='Healthcare Outcomes', type='Outcomes'), Node(id='Telemedicine Platform', type='Telemedicine platform'), Node(id='Remote Consultations', type='Consultations')], relationships=[Relationship(source=Node(id='Betahealth', type='Healthcare provider'), target=Node(id='Microsoft Azure', type='Cloud service'), type='HOSTING_PLATFORM'), Relationship(source=Node(id='Betahealth', type='Healthcare provider'), target=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), type='PLATFORM_DEVELOPMENT'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Data Insights', type='Insights'), type='DATA_ANALYSIS'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Resource Allocation', type='Resource allocation'), type='EFFICIENCY_IMPROVEMENT'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Patient Satisfaction', type='Satisfaction'), type='INCREASE'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Healthcare Outcomes', type='Outcomes'), type='IMPROVEMENT'), Relationship(source=Node(id='Betahealth', type='Healthcare provider'), target=Node(id='Telemedicine Platform', type='Telemedicine platform'), type='PLATFORM_DEVELOPMENT'), Relationship(source=Node(id='Telemedicine Platform', type='Telemedicine platform'), target=Node(id='Remote Consultations', type='Consultations'), type='INCREASE')], source=Document(page_content=" patient readmission rates and a 30% improvement in resource allocation efficiency, leading to increased patient satisfaction and improved healthcare outcomes.\n\nBrief: BetaHealth Secure Healthcare Data Analytics Platform on Azure\nCustomer Need: BetaHealth, a leading healthcare provider, is dedicated to advancing patient care through data analytics and AI. They require an advanced platform hosted on Microsoft Azure to provide secure, data-driven patient insights, optimize resource allocation, and improve healthcare outcomes while ensuring data privacy and compliance.\nDelivered Solution: We've created a Secure Healthcare Data Analytics Platform hosted on Microsoft Azure, leveraging cutting-edge technologies for data analysis and AI. This platform enables real-time patient monitoring, predictive analytics for disease management, and secure data handling to protect patient information. BetaHealth can now deliver personalized care while ensuring strict data privacy and compliance with healthcare regulations.\nTechnologies Involved: Our solution leverages Microsoft Azure services, such as Azure Databricks for data analytics, Azure Machine Learning for predictive modeling, Azure Key Vault for data encryption, and Azure Active Directory for access control. We also use Azure Synapse Analytics for data warehousing and Azure Logic Apps for workflow automation.\nTimeline & Customer Experience: The project unfolded over nine months, involving close collaboration with BetaHealth's healthcare professionals and data security experts. Since implementation, BetaHealth has seen a 25% reduction in patient readmission rates and a 30% improvement in resource allocation efficiency, all while maintaining the highest standards of data security and compliance.\n\nBrief: BetaHealth Telemedicine Platform on Microsoft Azure Customer Need: With the evolving healthcare landscape, BetaHealth aims to provide remote consultations and care to its patients. They envision a Telemed ...
#  GraphDocument(nodes=[Node(id='Deltaedu', type='Company'), Node(id='Ai-Powered Analytics Platform', type='Technology'), Node(id='Aws', type='Platform'), Node(id='Sagemaker', type='Service'), Node(id='Quicksight', type='Service'), Node(id='Dynamodb', type='Service'), Node(id='Lambda', type='Service'), Node(id='Virtual Classroom Platform', type='Technology'), Node(id='Chime', type='Service'), Node(id='Elastic Beanstalk', type='Service'), Node(id='Rds', type='Service'), Node(id='Epsilonfinance', type='Company'), Node(id='Mobile-First Digital Wallet', type='Technology'), Node(id='Google Cloud', type='Platform')], relationships=[Relationship(source=Node(id='Deltaedu', type='Company'), target=Node(id='Ai-Powered Analytics Platform', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Ai-Powered Analytics Platform', type='Technology'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Sagemaker', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Quicksight', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Dynamodb', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Lambda', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Deltaedu', type='Company'), target=Node(id='Virtual Classroom Platform', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Virtual Classroom Platform', type='Technology'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Chime', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Elastic Beanstalk', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Rds', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Epsilonfinance', type='Company'), target=Node(id='Mobile-First Digital Wallet', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Technology'), target=Node(id='Google Cloud', type='Platform'), type='HOSTED_ON')], source=Document(page_content=" in remote consultations, greatly enhancing patient accessibility.\n\nBrief: DeltaEdu AI-Powered Student Performance Analytics on AWS Customer Need: DeltaEdu wishes to gain deeper insights into student performance, identify learning gaps, and personalize the educational journey. They need an AI-driven analytics solution on AWS to achieve these objectives.\nDelivered Solution: We've introduced an AI-Powered Analytics platform on AWS, which analyzes student interactions, test scores, and feedback. The platform provides educators with insights to tailor teaching methodologies and offer personalized learning paths.\nTechnologies Involved: Our solution integrates AWS services such as SageMaker for machine learning, QuickSight for visualization, DynamoDB for data storage, and Lambda for serverless analytics functions.\nTimeline & Customer Experience: Over a six-month period, the platform was developed and refined in collaboration with DeltaEdu's academic and IT teams. Post-implementation, educators have reported a 25% improvement in identifying and addressing student learning gaps.\n\nBrief: DeltaEdu Virtual Classroom Platform on AWS Customer Need: In the wake of the digital transformation in education, DeltaEdu aims to create an interactive and engaging virtual classroom experience. They are looking for a scalable solution on the AWS platform to conduct online classes and workshops.\nDelivered Solution: We have designed a Virtual Classroom Platform on AWS, allowing DeltaEdu to host live sessions, interactive discussions, and hands-on workshops. With features like real-time quizzes, breakout rooms, and collaborative whiteboards, the platform enriches the ...
#  GraphDocument(nodes=[Node(id='Epsilonfinance', type='Company'), Node(id='Mobile-First Digital Wallet', type='Product'), Node(id='Google Cloud', type='Technology'), Node(id='Firebase', type='Technology'), Node(id='Firestore', type='Technology'), Node(id='Cloud Functions', type='Technology'), Node(id='Google Pay Apis', type='Technology'), Node(id='Gammatech', type='Company'), Node(id='Autonomous Fleet Management System', type='Product'), Node(id='Microsoft Azure', type='Technology'), Node(id='Azure Iot Hub', type='Technology'), Node(id='Azure Functions', type='Technology'), Node(id='Azure Machine Learning', type='Technology'), Node(id='Azure Blob Storage', type='Technology'), Node(id='Azure Logic Apps', type='Technology'), Node(id='Azure Monitor', type='Technology')], relationships=[Relationship(source=Node(id='Epsilonfinance', type='Company'), target=Node(id='Mobile-First Digital Wallet', type='Product'), type='DEVELOPED'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Google Cloud', type='Technology'), type='HOSTED_ON'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Firebase', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Firestore', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Cloud Functions', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Google Pay Apis', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Autonomous Fleet Management System', type='Product'), type='DEVELOPED'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Microsoft Azure', type='Technology'), type='HOSTED_ON'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Iot Hub', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Functions', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Machine Learning', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Blob Storage', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Logic Apps', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Monitor', type='Technology'), type='UTILIZES')], source=Document(page_content="\nDelivered Solution: We've developed a Mobile-First Digital Wallet for EpsilonFinance on Google Cloud. The app supports instant transactions, integrates with various banks, and offers curated deals and loyalty rewards to users.\nTechnologies Involved: The app leverages Google Cloud services such as Firebase for backend operations, Firestore for real-time data storage, Cloud Functions for serverless computing, and Google Pay APIs for payment integrations.\nTimeline & Customer Experience: The project, completed in seven months, saw EpsilonFinance's vision transformed into a market-ready app. Since its release, the app has garnered over 100,000 downloads with a 4.8-star rating on app stores.\nWould you like these briefs saved as individual files, or is there anything else you'd like to adjust?\n\nBrief: GammaTech Autonomous Fleet Management System on Azure\nCustomer Need: GammaTech, a transportation and logistics company, is in search of a state-of-the-art solution to manage their expanding fleet of autonomous vehicles. They require a comprehensive pla ...
#  GraphDocument(nodes=[Node(id='Smart Logistics Platform', type='Platform'), Node(id='Microsoft Azure', type='Technology'), Node(id='Real-Time Vehicle Monitoring', type='Feature'), Node(id='Route Optimization', type='Feature'), Node(id='Safety Enhancement', type='Feature'), Node(id='Efficiency Enhancement', type='Feature'), Node(id='Gammatech', type='Customer'), Node(id='Azure Iot Hub', type='Service'), Node(id='Azure Functions', type='Service'), Node(id='Azure Machine Learning', type='Service'), Node(id='Azure Cosmos Db', type='Service'), Node(id='Azure Devops', type='Service')], relationships=[Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Microsoft Azure', type='Technology'), type='HOSTED_ON'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Real-Time Vehicle Monitoring', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Route Optimization', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Safety Enhancement', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Efficiency Enhancement', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Gammatech', type='Customer'), target=Node(id='Smart Logistics Platform', type='Platform'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Iot Hub', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Functions', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Machine Learning', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Cosmos Db', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Devops', type='Service'), type='UTILIZES')], source=Document(page_content=" solution to optimize their evolving fleet management needs. They require a comprehensive platform hosted on Microsoft Azure that can provide real-time vehicle monitoring and control, route optimization, and enhance the safety and efficiency of their operations.\nDelivered Solution: We have developed a Smart Logistics Platform hosted on Microsoft Azure, incorporating cutting-edge technologies for real-time logistics management. This platform offers real-time vehicle tracking, route optimization using AI algorithms, and predictive maintenance to reduce downtime. GammaTech now has a centralized system ensuring the safety and efficiency of their logistics operations.\nTechnologies Involved: Our solution utilizes Microsoft Azure services, including Azure IoT Hub for real-time data from vehicles, Azure Functions for event-driven control, and Azure Machine Learning for predictive maintenance and route optimization. Azure Cosmos DB stores real-time data, and Azure DevOps streamlines development and deployment processes.\nTimeline & Customer Experience: The project was successfully delivered within a year, closely collaborating with GammaTech's logistics and fleet management teams. Since implementation, GammaTech has achieved a 20% reduction in fuel consumption, a 15% improvement in delivery times, and a 30% decrease in maintenance costs, establishing themselves as a leader in smart logistics within the industry.", metadata={'source': 'Data/Projects.txt'})),
#  GraphDocument(nodes=[Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Amanda Rodriguez', type='Person'), Node(id='Jason Mitchell', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Betahealth', type='Organization'), Node(id='Alphacorp', type='Organization'), Node(id='Gammatech', type='Organization'), Node(id='Azure', type='Technology'), Node(id='Aws', type='Technology'), Node(id='Ec2', type='Technology'), Node(id='Sagemaker', type='Technology'), Node(id='Iot', type='Technology')], relationships=[Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Betahealth', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Alphacorp', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Betahealth', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Gammatech', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Betahealth', type='Organization'), target=Node(id='Azure', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Alphacorp', type='Organization'), target=Node(id='Aws', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Alphacorp', type='Organization'), target=Node(id='Ec2', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Alphacorp', type='Organization'), target=Node(id='Sagemaker', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Gammatech', type='Organization'), target=Node(id='Azure', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Gammatech', type='Organization'), target=Node(id='Iot', type='Technology'), type='USES_TECHNOLOGY')], source=Document(page_content='\n        "id": "kcojvioa",\n        "type": "message",\n        "user": "Sarah Johnson",\n        "text": "I\'ve been working on BetaHealth\'s Azure-based data analytics platform. It\'s a game-changer for patient care. Collaborating with healthcare professionals has been invaluable."\n    \n    \n        "id": "asjdnifkjasd",\n        "type": "message",\n        "user": "David Patel",\n        "text": "AlphaCorp\'s AWS-powered supply chain optimization project has been both challenging and rewarding. AWS services like EC2 and SageMaker have made a real difference."\n    \n    \n        "id": "asdffjasd",\n        "type": "message",\n        "user": "Amanda Rodriguez",\n        "text": "Data security and compliance have been my top priorities in BetaHealth\'s Azure project. It\'s vital to protect patient information while advancing healthcare."\n    \n    \n        "id": "lklklkhg",\n        "type": "message",\n        "user": "Jason Mitchell",\n        "text": "Working on GammaTech\'s Azure-based smart logistics platform has been fascinating. Real-time logistics management is transforming the transportation industry."\n    \n    \n        "id": "jtthh",\n        "type": "message",\n        "user": "Emily Turner",\n        "text": "The IoT integration in GammaTech\'s Azure project is exciting. Azure technologies have truly revolutionized how we manage logistics operations."\n    \n    \n        "id": "heaas",\n     ', metadata={'source': 'Data/slackmsg.txt'})),
#  GraphDocument(nodes=[Node(id='Olivia Martinez', type='Person'), Node(id='William Lee', type='Person'), Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Alphacorp', type='Company'), Node(id='Aws', type='Service'), Node(id='Ec2', type='Service'), Node(id='Sagemaker', type='Service'), Node(id='Betahealth', type='Company'), Node(id='Azure', type='Service'), Node(id='Ml', type='Capability'), Node(id='Gammatech', type='Company')], relationships=[Relationship(source=Node(id='Olivia Martinez', type='Person'), target=Node(id='Alphacorp', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='William Lee', type='Person'), target=Node(id='Betahealth', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Alphacorp', type='Company'), type='WORKED_ON_SAME_PROJECT'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='David Patel', type='Person'), type='ASKED_ABOUT_PROJECT_EXPERIENCE'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Alphacorp', type='Company'), type='SHARED_EXPERIENCE'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Aws', type='Service'), type='EXPERIENCED_BENEFITS'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Supply Chain', type='Domain'), type='IMPROVEMENTS_IN'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech', type='Company'), type='ASKED_ABOUT_PROJECT_EXPERIENCE')], source=Document(page_content='   \n        "id": "heaas",\n        "type": "message",\n        "user": "Olivia Martinez",\n        "text": "Monitoring efficiency improvements in AlphaCorp\'s AWS project is fascinating. AWS services like EC2 and SageMaker are making a real impact."\n    \n    \n        "id": "jsssa",\n        "type": "message",\n        "user": "William Lee",\n        "text": "Applying predictive modeling in BetaHealth\'s Azure project is exciting. Collaborating with healthcare professionals and Azure\'s ML capabilities are key."\n    \n    \n        "id": "ppaa",\n        "type": "message",\n        "user": "Sarah Johnson",\n        "text": "David, I noticed you worked on the AlphaCorp AWS project too. How was your experience with it?"\n    \n    \n        "id": "gfdd",\n        "type": "message",\n        "user": "David Patel",\n        "text": "Sarah, it was quite challenging but rewarding. We\'ve seen significant cost reductions and improved deliveries in their supply chain."\n    \n    \n        "id": "lopyyy",\n        "type": "message",\n        "user": "Emily Turner",\n        "text": "Jason, I\'m curious about your experience with real-time logistics in the GammaTech project. Any key takeaways?"\n    \n    \n        "id": "fgtttta",\n        "type": "message",\n        "user": "Jason Mitchell",\n       ', metadata={'source': 'Data/slackmsg.txt'})),
#  GraphDocument(nodes=[Node(id='Jason Mitchell', type='Person'), Node(id='Emily', type='Person'), Node(id='Azure Iot Hub', type='Technology'), Node(id='Functions', type='Technology'), Node(id='Olivia Martinez', type='Person'), Node(id='Michael Clark', type='Person'), Node(id='Alphacorp', type='Company'), Node(id='Aws', type='Technology'), Node(id='Ec2', type='Technology'), Node(id='Sagemaker', type='Technology'), Node(id='Jessica White', type='Person'), Node(id='Betahealth', type='Company'), Node(id='Azure Key Vault', type='Technology'), Node(id='Daniel Brown', type='Person'), Node(id='Gammatech', type='Company')], relationships=[Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Emily', type='Person'), type='COLLEAGUE'), Relationship(source=Node(id='Olivia Martinez', type='Person'), target=Node(id='Michael Clark', type='Person'), type='COLLEAGUE'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Alphacorp', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Aws', type='Technology'), type='USES'), Relationship(source=Node(id='Aws', type='Technology'), target=Node(id='Ec2', type='Technology'), type='DRIVES_COST_REDUCTIONS'), Relationship(source=Node(id='Aws', type='Technology'), target=Node(id='Sagemaker', type='Technology'), type='DRIVES_COST_REDUCTIONS'), Relationship(source=Node(id='Jessica White', type='Person'), target=Node(id='Betahealth', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Betahealth', type='Company'), target=Node(id='Azure Key Vault', type='Technology'), type='IMPLEMENTS'), Relationship(source=Node(id='Daniel Brown', type='Person'), target=Node(id='Gammatech', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Azure Iot Hub', type='Technology'), type='USES'), Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Functions', type='Technology'), type='USES')], source=Document(page_content='",\n        "user": "Jason Mitchell",\n        "text": "Emily, real-time logistics is all about efficiency. Azure IoT Hub and Functions have made our logistics operations highly responsive."\n    \n    \n        "id": "pldfpaks",\n        "type": "message",\n        "user": "Olivia Martinez",\n        "text": "Michael, how\'s the monitoring going in the AlphaCorp AWS project? Any interesting insights you\'ve gained?"\n    \n    \n        "id": "ytthf",\n        "type": "message",\n        "user": "Michael Clark",\n        "text": "The data engineering challenge in AlphaCorp\'s AWS project has been rewarding. AWS services like EC2 and SageMaker have driven cost reductions."\n    \n    \n        "id": "agaer",\n        "type": "message",\n        "user": "Jessica White",\n        "text": "Ensuring data privacy in BetaHealth\'s Azure project is crucial. Collaborating with healthcare professionals and implementing Azure Key Vault is a must."\n    \n    \n        "id": "bbtgg",\n        "type": "message",\n        "user": "Daniel Brown",\n        "text": "Optimizing logistics operations in GammaTech\'s Azure project is a great journey. Azure IoT Hub and Functions are pivotal for efficiency."\n    \n    \n        "id": "gapaa",\n        "type": "message",\n        "user": "Michael Clark",\n        "text": "Olivia, it\'s been fascinating. We\'ve uncovered insights that have led to cost reductions and better on', metadata={'source': 'Data/slackmsg.txt'})),
#  GraphDocument(nodes=[Node(id='Olivia', type='Person'), Node(id='Emma Martinez', type='Person'), Node(id='Sophia Anderson', type='Person'), Node(id='Ava Jackson', type='Person'), Node(id='Aiden Lewis', type='Person'), Node(id='Lucas Taylor', type='Person'), Node(id='Epsilonfinance', type='Company'), Node(id='Google Pay Apis', type='Technology'), Node(id='Google Cloud', type='Technology'), Node(id='Alphacorp', type='Company'), Node(id='Deltaedu', type='Company'), Node(id='Real-Time Monitoring', type='Concept'), Node(id='Digital Wallet', type='Product'), Node(id='Security Features', type='Concept'), Node(id='Visualization Module', type='Product'), Node(id='Insights', type='Concept'), Node(id='Breakout Rooms', type='Product'), Node(id='Virtual Classroom', type='Product')], relationships=[Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Epsilonfinance', type='Company'), type='HAS_WORKED_IN'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Epsilonfinance', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Epsilonfinance', type='Company'), type='HAS_MENTIONED_SECURITY'), Relationship(source=Node(id='Ava Jackson', type='Person'), target=Node(id='Alphacorp', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Alphacorp', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Lucas Taylor', type='Person'), target=Node(id='Deltaedu', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Real-Time Monitoring', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Insights', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Cost Reductions', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Better On-Time Deliveries', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Google Pay Apis', type='Technology'), type='HAS_INTEGRATED_WITH'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Google Cloud', type='Technology'), type='HAS_MENTIONED'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Security Features', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Ava Jackson', type='Person'), target=Node(id='Visualization Module', type='Product'), type='HAS_MENTIONED'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Visualization Module', type='Product'), type='HAS_MENTIONED'), Relationship(source=Node(id='Lucas Taylor', type='Person'), target=Node(id='Breakout Rooms', type='Product'), type='HAS_MENTIONED'), Relationship(source=Node(id='Lucas Taylor', type='Person'), target=Node(id='Virtual Classroom', type='Product'), type='HAS_MENTIONED')], source=Document(page_content='": "Olivia, it\'s been fascinating. We\'ve uncovered insights that have led to cost reductions and better on-time deliveries. Real-time monitoring is key."\n    \n\n        "id": "6cffae64-d",\n        "type": "message",\n        "user": "Emma Martinez",\n        "text": "EpsilonFinance\'s Digital Wallet is so user-friendly. The integration with Google Pay APIs has made transactions smooth."\n    \n    \n        "id": "c9e872b6-a",\n        "type": "message",\n        "user": "Sophia Anderson",\n        "text": "Securing user data in EpsilonFinance\'s Digital Wallet has been top priority. Google Cloud\'s security features have been instrumental."\n    \n    \n        "id": "944dd6bb-6",\n        "type": "message",\n        "user": "Ava Jackson",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so  ...
#  GraphDocument(nodes=[Node(id='Deltaedu', type='Organization'), Node(id='Virtual Classroom', type='Room')], relationships=[Relationship(source=Node(id='Deltaedu', type='Organization'), target=Node(id='Virtual Classroom', type='Room'), type='HAS')], source=Document(page_content=' rooms in DeltaEdu\'s Virtual Classroom? I\'d love to get feedback."\n    \n    \n        "id": "e756c8ae-c",\n        "type": "message",\n        "user": "Emma Martinez",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so detailed."\n    \n    \n        "id": "6674380b-6",\n        "type": "message",\n        "user": "Ava Jackson",\n        "text": "The personalized learning paths suggested by our AI model for DeltaEdu are spot on. Kudos to the team!"\n    \n    \n        "id": "241c3938-c",\n        "type": "message",\n        "user": "Benjamin White",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so detailed."\n    \n    \n        "id": "877c0c6d-3",\n        "type": "message",\n        "user": "Lucas Taylor",\n        "text": "The remote monitoring in BetaHealth\'s Telemedicine Platform ensures continuous patient care. Azure\'s scalability made it possible."\n    \n\n        "id": "e1bfefde-f",\n        "type": "message",\n        "user": "Ella Smith",\n        "text": "Has anyone tried the breakout rooms in DeltaEdu\'s Virtual Classroom? I\'d love to get feedback."\n    \n    \n        "id": "6ec813a6-0",\n ', metadata={'source': 'Data/slackmsg.txt'})),
#  GraphDocument(nodes=[Node(id='Noah Wilson', type='User'), Node(id='Aiden Lewis', type='User'), Node(id='Benjamin White', type='User'), Node(id='Sophia Anderson', type='User'), Node(id='Alphacorp', type='Company'), Node(id='Gammatech', type='Company'), Node(id='Betahealth', type='Company'), Node(id='Epsilonfinance', type='Company'), Node(id='Azure', type='Technology')], relationships=[Relationship(source=Node(id='Noah Wilson', type='User'), target=Node(id='Alphacorp', type='Company'), type='EXPLORED_VISUALIZATION_MODULE'), Relationship(source=Node(id='Aiden Lewis', type='User'), target=Node(id='Gammatech', type='Company'), type='REDUCED_DOWNTIMES'), Relationship(source=Node(id='Benjamin White', type='User'), target=Node(id='Betahealth', type='Company'), type='UTILIZED_REMOTE_MONITORING'), Relationship(source=Node(id='Betahealth', type='Company'), target=Node(id='Azure', type='Technology'), type='UTILIZED_SCALABILITY'), Relationship(source=Node(id='Sophia Anderson', type='User'), target=Node(id='Epsilonfinance', type='Company'), type='TESTED_LOYALTY_REWARDS_FEATURE'), Relationship(source=Node(id='Sophia Anderson', type='User'), target=Node(id='Epsilonfinance', type='Company'), type='TESTED_USER_ENGAGEMENT'), Relationship(source=Node(id='Sophia Anderson', type='User'), target=Node(id='Betahealth', type='Company'), type='EXPERIENCED_PATIENT_DATA_SECURITY_CHALLENGE'), Relationship(source=Node(id='Betahealth', type='Company'), target=Node(id='Azure', type='Technology'), type='UTILIZED_SECURITY_CENTER')], source=Document(page_content=' \n        "id": "6ec813a6-0",\n        "type": "message",\n        "user": "Noah Wilson",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so detailed."\n    \n    \n        "id": "4203972a-d",\n        "type": "message",\n        "user": "Aiden Lewis",\n        "text": "GammaTech\'s Manufacturing Monitoring System has significantly reduced downtimes. Real-time monitoring is the future."\n    \n    \n        "id": "f230a0f7-a",\n        "type": "message",\n        "user": "Benjamin White",\n        "text": "The remote monitoring in BetaHealth\'s Telemedicine Platform ensures continuous patient care. Azure\'s scalability made it possible."\n    \n    \n        "id": "843bab5f-a",\n        "type": "message",\n        "user": "Sophia Anderson",\n        "text": "I\'ve been testing the loyalty rewards feature in EpsilonFinance\'s app. The user engagement is bound to skyrocket!"\n    \n\n        "id": "408133de-0",\n        "type": "message",\n        "user": "Sophia Anderson",\n        "text": "Patient data security in BetaHealth\'s Telemedicine Platform has been a challenge, but Azure Security Center has been a great help."\n    \n    \n        "id": "f17f60cc-0",\n        "type": "message",\n  ', metadata={'source': 'Data/slackmsg.txt'})),
#  GraphDocument(nodes=[Node(id='Gammatech', type='Company'), Node(id='Azure Digital Twins', type='Technology'), Node(id='Deltaedu', type='Company'), Node(id='Aws', type='Technology'), Node(id='Epsilonfinance', type='Company'), Node(id='Google Pay Apis', type='Technology')], relationships=[Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Azure Digital Twins', type='Technology'), type='USES'), Relationship(source=Node(id='Deltaedu', type='Company'), target=Node(id='Aws', type='Technology'), type='USES'), Relationship(source=Node(id='Epsilonfinance', type='Company'), target=Node(id='Google Pay Apis', type='Technology'), type='INTEGRATES')], source=Document(page_content='17f60cc-0",\n        "type": "message",\n        "user": "Liam Thompson",\n        "text": "The virtual representation of the manufacturing unit using Azure Digital Twins for GammaTech is fascinating. It\'s like having a digital twin of the entire facility."\n    \n    \n        "id": "01e37dce-1",\n        "type": "message",\n        "user": "Lucas Taylor",\n        "text": "The Virtual Classroom Platform for DeltaEdu on AWS is shaping up really well. The real-time quizzes feature is a hit!"\n    \n    \n        "id": "158f781f-8",\n        "type": "message",\n        "user": "Emma Martinez",\n        "text": "GammaTech\'s Manufacturing Monitoring System has significantly reduced downtimes. Real-time monitoring is the future."\n    \n    \n        "id": "afc5f40e-b",\n        "type": "message",\n        "user": "Isabella Harris",\n        "text": "EpsilonFinance\'s Digital Wallet is so user-friendly. The integration with Google Pay APIs has made transactions smooth."\n    \n    \n        "id": "a00bdb25-0",\n        "type": "message",\n        "user": "Ella Smith",\n        "text": "The virtual representation of the manufacturing unit using Azure Digital Twins for GammaTech is fascinating. It\'s like having a digital twin of the entire facility."\n    \n\n', metadata={'source': 'Data/slackmsg.txt'}))]

# %%
graph.add_graph_documents(graph_documents)

# %%
print(f"Nodes:{graph_documents[0].nodes}")
print(f"Relationships:{graph_documents[0].relationships}")
# Out:
# Nodes:[Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Amanda Rodriguez', type='Person'), Node(id='Jason Mitchell', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Michael Clark', type='Person'), Node(id='Jessica White', type='Person'), Node(id='Daniel Brown', type='Person'), Node(id='Olivia Martinez', type='Person'), Node(id='William Lee', type='Person'), Node(id='Ella Smith', type='Person'), Node(id='Lucas Taylor', type='Person'), Node(id='Liam Thompson', type='Person')]
# Relationships:[Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Aws', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Cloud Computing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Devops', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Data Security', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Compliance', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Healthcare Regulations', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Iot', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Real-Time Data Management', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Engineering', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Aws', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Alphacorp Aws-Powered Supply Chain Optimization Platform', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Jessica White', type='Person'), target=Node(id='Data Privacy', type ...

# %%
llm_transformer = LLMGraphTransformer(
    llm=llm,
    allowed_nodes=["PERSON", "SKILLS", "PROJECTS"],
    allowed_relationships=["PART_OF", "HAS_PEOPLE", "HAS", "IS_A"],
)
graph_documents_filtered = llm_transformer.convert_to_graph_documents(
    documents
)
print(f"Nodes:{graph_documents[0].nodes}")
print(f"Relationships:{graph_documents[0].relationships}")
# Out:
# Nodes:[Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Amanda Rodriguez', type='Person'), Node(id='Jason Mitchell', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Michael Clark', type='Person'), Node(id='Jessica White', type='Person'), Node(id='Daniel Brown', type='Person'), Node(id='Olivia Martinez', type='Person'), Node(id='William Lee', type='Person'), Node(id='Ella Smith', type='Person'), Node(id='Lucas Taylor', type='Person'), Node(id='Liam Thompson', type='Person')]
# Relationships:[Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Aws', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Cloud Computing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Devops', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Data Security', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Compliance', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Healthcare Regulations', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Iot', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Real-Time Data Management', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Engineering', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Aws', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Alphacorp Aws-Powered Supply Chain Optimization Platform', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Jessica White', type='Person'), target=Node(id='Data Privacy', type ...

# %%
graph = Neo4jGraph(NEO4J_CONNECTION_URL, NEO4J_USER, NEO4J_PASSWORD)

# %% [markdown]
# The GraphCycherQAChain abstracts all the details and outputs a natural language response for a natural language question(NLQ). However, internally it uses LLMs to generate a Cypher query for an NLQ and retrieves graph result from the graph database and finally uses those result to generate the final natural language response, again using an LLM.

# %%
chain = GraphCypherQAChain.from_llm(
    graph=graph, llm=llm, verbose=True, validate_cypher=True
)

# %%
chain.invoke({"query": "Which person uses the largest number of different technologies?"})
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:HAS_SKILL]->(t:Technology)
# WITH p, COUNT(DISTINCT t) AS numTech
# RETURN p
# ORDER BY numTech DESC
# LIMIT 1
# Full Context:
# [{'p': {'id': 'Sarah Johnson'}}]
#
# > Finished chain.
# {'query': 'Which person uses the largest number of different technologies?',
#  'result': 'Sarah Johnson uses the largest number of different technologies.'}

# %%
chain.invoke({"query": " Which person has more project?"})
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:WORKS_ON]->(pr:Project)
# WITH p, COUNT(pr) AS numProjects
# RETURN p.id, numProjects
# ORDER BY numProjects DESC
# LIMIT 1
# Full Context:
# [{'p.id': 'Isabella Harris', 'numProjects': 1}]
#
# > Finished chain.
# {'query': ' Which person has more project?',
#  'result': 'Isabella Harris has 1 project.'}

# %%
chain.invoke({"query": " List all the projects??"})
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Project)
# RETURN p;
# Full Context:
# [{'p': {'id': 'Alphacorp Aws-Powered Supply Chain Optimization Platform'}}, {'p': {'id': 'Betahealth Secure Healthcare Data Analytics Platform On Azure'}}, {'p': {'id': 'Gammatech Smart Logistics Platform On Azure'}}, {'p': {'id': 'Betahealth Telemedicine Platform On Microsoft Azure'}}, {'p': {'id': 'Alphacorp Aws-Powered Sales Analytics Dashboard'}}, {'p': {'id': 'Deltaedu Virtual Classroom Platform On Aws'}}, {'p': {'id': 'Gammatech Iot-Driven Manufacturing Monitoring System On Azure'}}, {'p': {'id': 'Epsilonfinance Mobile-First Digital Wallet On Google Cloud'}}, {'p': {'id': 'Ai-Powered Student Performance Analytics On Aws'}}, {'p': {'id': 'Timeline & Customer Experience'}}]
#
# > Finished chain.
# {'query': ' List all the projects??', 'result': "I don't know the answer."}

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Amanda Rodriguez', type='Person'), Node(id='Jason Mitchell', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Michael Clark', type='Person'), Node(id='Jessica White', type='Person'), Node(id='Daniel Brown', type='Person'), Node(id='Olivia Martinez', type='Person'), Node(id='William Lee', type='Person'), Node(id='Ella Smith', type='Person'), Node(id='Lucas Taylor', type='Person'), Node(id='Liam Thompson', type='Person')], relationships=[Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Aws', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Cloud Computing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Devops', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Data Security', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Compliance', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Healthcare Regulations', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Betahealth Secure Healthcare Data Analytics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Iot', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Real-Time Data Management', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Azure', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech Smart Logistics Platform On Azure', type='Project'), type='WORKED_ON_PROJECT'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Engineering', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Data Warehousi ...
#  GraphDocument(nodes=[Node(id='Platform On Aws', type='Platform'), Node(id='Gammatech Iot-Driven Manufacturing Monitoring System', type='System'), Node(id='Azure', type='Cloud service'), Node(id='Sophia Anderson', type='Person'), Node(id='Data Analytics', type='Skill'), Node(id='Machine Learning', type='Skill'), Node(id='Data Warehousing', type='Skill'), Node(id='Betahealth Telemedicine Platform', type='Project'), Node(id='Aiden Lewis', type='Person'), Node(id='Iot', type='Skill'), Node(id='Real-Time Data Management', type='Skill'), Node(id='Python', type='Skill'), Node(id='Emma Martinez', type='Person'), Node(id='Data Engineering', type='Skill'), Node(id='Aws', type='Cloud service'), Node(id='Alphacorp Aws-Powered Sales Analytics Dashboard', type='Project'), Node(id='Deltaedu Virtual Classroom Platform', type='Project'), Node(id='Noah Wilson', type='Person'), Node(id='Data Privacy', type='Skill'), Node(id='Security Compliance', type='Skill'), Node(id='Azure Key Vault', type='Skill'), Node(id='Healthcare Regulations', type='Skill'), Node(id='Ava Jackson', type='Person'), Node(id='Cloud Architecture', type='Skill'), Node(id='Devops', type='Skill'), Node(id='Aws Lambda', type='Skill'), Node(id='Azure Functions', type='Skill'), Node(id='Benjamin White', type='Person'), Node(id='Real-Time Monitoring', type='Skill'), Node(id='Azure Monitoring', type='Skill'), Node(id='Isabella Harris', type='Person'), Node(id='Predictive Modeling', type='Skill'), Node(id='Aws Sagemaker', type='Skill'), Node(id='Azure Machine Learning', type='Skill'), Node(id='Epsilonfinance Mobile-First Digital Wallet', type='Project'), Node(id='Google Cloud', type='Cloud service')], relationships=[Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Data Analytics', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Machine Learning', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Azure', type='Cloud service'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Betahealth Telemedicine Platform', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Iot', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Real-Time Data Management', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Azure', type='Cloud service'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Betahealth Telemedicine Platform', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Data Engineering', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Data Warehousing', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Aws', type='Cloud service'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Python', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Alphacorp Aws-Powered Sales Analytics Dashboard', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Deltaedu Virtual Classroom Platform', type='Project'), type='WORKED_ON'), Relationship(source=Node(id='Noah Wilson', type='Person'), target=Node(id='Data Privacy', type='Skill'), type='HAS_SKILL'), Relationship(source=Node(id='Noah Wilson', type='Perso ...
#  GraphDocument(nodes=[Node(id='Alphacorp', type='Company'), Node(id='Sales Analytics Dashboard', type='Dashboard'), Node(id='Aws', type='Platform'), Node(id='Sales Teams', type='Team'), Node(id='Executives', type='Team'), Node(id='Quicksight', type='Service'), Node(id='Redshift', type='Service'), Node(id='Lambda', type='Service'), Node(id='S3', type='Service'), Node(id='Customer Support Chatbot', type='Chatbot'), Node(id='Natural Language Processing', type='Algorithm'), Node(id='Machine Learning', type='Algorithm'), Node(id='Crm System', type='System'), Node(id='Dynamodb', type='Database'), Node(id='Cloudwatch', type='Monitoring tool'), Node(id='Api Gateway', type='Api management'), Node(id='Customer Support Team', type='Team'), Node(id='Supply Chain Optimization Platform', type='Platform'), Node(id='Suppliers', type='Entity'), Node(id='Distribution Centers', type='Entity')], relationships=[Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Sales Analytics Dashboard', type='Dashboard'), type='UTILIZES'), Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Customer Support Chatbot', type='Chatbot'), type='UTILIZES'), Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Supply Chain Optimization Platform', type='Platform'), type='UTILIZES'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Quicksight', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Redshift', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='Lambda', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Sales Analytics Dashboard', type='Dashboard'), target=Node(id='S3', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Lambda', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Lex', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='S3', type='Service'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Dynamodb', type='Database'), type='USES_DATABASE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Cloudwatch', type='Monitoring tool'), type='USES_TOOL'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Api Gateway', type='Api management'), type='USES_SERVICE'), Relationship(source=Node(id='Customer Support Chatbot', type='Chatbot'), target=Node(id='Crm System', type='System'), type='INTEGRATES_WITH'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Suppliers', type='Entity'), type='MANAGES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Distribution Centers', type='Entity'), type='MANAGES')], source=Document(page_content="Brief: AlphaCorp AWS-Powered Sales Analytics Dashboard\nCustomer Need: AlphaCorp is keen on understanding its sales trends, customer behaviors, and product performance in real-time. They need an intuitive dashboard hosted on the AWS platform for their sales teams and executives to make informed decisions.\nDelivered Solution: We have built a Sales Analytics Dashboard hosted on AWS, providing real-time insights into sales metrics, customer segmentation, and product performance. The dashboard, with its drill-down capabilities, ...
#  GraphDocument(nodes=[Node(id='Supply Chain Optimization Platform', type='Platform'), Node(id='Aws', type='Cloud service provider'), Node(id='Alphacorp', type='Company'), Node(id='Technologies', type='Technology'), Node(id='Ec2', type='Service'), Node(id='Sagemaker', type='Service'), Node(id='Rds', type='Service'), Node(id='S3', type='Service'), Node(id='Lambda', type='Service'), Node(id='Cloudwatch', type='Service'), Node(id='Supply Chain', type='Process'), Node(id='Inventory Levels', type='Data'), Node(id='Order Fulfillment', type='Process'), Node(id='Transportation Logistics', type='Process'), Node(id='Predictive Analytics', type='Technology'), Node(id='Disruptions', type='Event'), Node(id='Procurement Strategies', type='Process'), Node(id='Reduction In Costs', type='Outcome'), Node(id='On-Time Deliveries', type='Outcome'), Node(id='Competitive Edge', type='Outcome'), Node(id='Betahealth Ai-Driven Patient Care Enhancement Platform', type='Platform'), Node(id='Azure', type='Cloud service provider'), Node(id='Betahealth', type='Company'), Node(id='Healthcare Provider', type='Role'), Node(id='Ai And Data Analytics', type='Technology'), Node(id='Personalized Patient Insights', type='Data'), Node(id='Resource Allocation', type='Process'), Node(id='Healthcare Outcomes', type='Outcome'), Node(id='Patient Monitoring', type='Process'), Node(id='Disease Management', type='Process'), Node(id='Resource Allocation For Healthcare Facilities', type='Process'), Node(id='Personalized Care', type='Outcome'), Node(id='Operational Efficiency', type='Outcome'), Node(id='Machine Learning', type='Technology'), Node(id='Data Analytics', type='Technology'), Node(id='Azure Virtual Machines', type='Service'), Node(id='Azure Machine Learning', type='Service'), Node(id='Azure Functions', type='Service'), Node(id='Azure Sql Database', type='Service'), Node(id='Azure Iot', type='Service'), Node(id='Azure Cognitive Services', type='Service'), Node(id='Patient Data', type='Data'), Node(id='Medical Records', type='Data'), Node(id='Natural Language Processing', type='Process'), Node(id='Readmission Rates', type='Outcome'), Node(id='Patient Satisfaction', type='Outcome')], relationships=[Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Supply Chain Optimization Platform', type='Platform'), type='UTILIZES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Aws', type='Cloud service provider'), type='HOSTED_ON'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Technologies', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Ec2', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Sagemaker', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Rds', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='S3', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Lambda', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Technologies', type='Technology'), target=Node(id='Cloudwatch', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Supply Chain', type='Process'), type='OPTIMIZES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Reduction In Costs', type='Outcome'), type='ACHIEVES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='On-Time Deliveries', type='Outcome'), type='ACHIEVES'), Relationship(source=Node(id='Supply Chain Optimization Platform', type='Platform'), target=Node(id='Competitive Edge', type='Outcome'), type='ENH ...
#  GraphDocument(nodes=[Node(id='Betahealth', type='Healthcare provider'), Node(id='Microsoft Azure', type='Cloud service'), Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), Node(id='Data Insights', type='Insights'), Node(id='Resource Allocation', type='Resource allocation'), Node(id='Patient Satisfaction', type='Satisfaction'), Node(id='Healthcare Outcomes', type='Outcomes'), Node(id='Telemedicine Platform', type='Telemedicine platform'), Node(id='Remote Consultations', type='Consultations')], relationships=[Relationship(source=Node(id='Betahealth', type='Healthcare provider'), target=Node(id='Microsoft Azure', type='Cloud service'), type='HOSTING_PLATFORM'), Relationship(source=Node(id='Betahealth', type='Healthcare provider'), target=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), type='PLATFORM_DEVELOPMENT'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Data Insights', type='Insights'), type='DATA_ANALYSIS'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Resource Allocation', type='Resource allocation'), type='EFFICIENCY_IMPROVEMENT'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Patient Satisfaction', type='Satisfaction'), type='INCREASE'), Relationship(source=Node(id='Secure Healthcare Data Analytics Platform', type='Data analytics platform'), target=Node(id='Healthcare Outcomes', type='Outcomes'), type='IMPROVEMENT'), Relationship(source=Node(id='Betahealth', type='Healthcare provider'), target=Node(id='Telemedicine Platform', type='Telemedicine platform'), type='PLATFORM_DEVELOPMENT'), Relationship(source=Node(id='Telemedicine Platform', type='Telemedicine platform'), target=Node(id='Remote Consultations', type='Consultations'), type='INCREASE')], source=Document(page_content=" patient readmission rates and a 30% improvement in resource allocation efficiency, leading to increased patient satisfaction and improved healthcare outcomes.\n\nBrief: BetaHealth Secure Healthcare Data Analytics Platform on Azure\nCustomer Need: BetaHealth, a leading healthcare provider, is dedicated to advancing patient care through data analytics and AI. They require an advanced platform hosted on Microsoft Azure to provide secure, data-driven patient insights, optimize resource allocation, and improve healthcare outcomes while ensuring data privacy and compliance.\nDelivered Solution: We've created a Secure Healthcare Data Analytics Platform hosted on Microsoft Azure, leveraging cutting-edge technologies for data analysis and AI. This platform enables real-time patient monitoring, predictive analytics for disease management, and secure data handling to protect patient information. BetaHealth can now deliver personalized care while ensuring strict data privacy and compliance with healthcare regulations.\nTechnologies Involved: Our solution leverages Microsoft Azure services, such as Azure Databricks for data analytics, Azure Machine Learning for predictive modeling, Azure Key Vault for data encryption, and Azure Active Directory for access control. We also use Azure Synapse Analytics for data warehousing and Azure Logic Apps for workflow automation.\nTimeline & Customer Experience: The project unfolded over nine months, involving close collaboration with BetaHealth's healthcare professionals and data security experts. Since implementation, BetaHealth has seen a 25% reduction in patient readmission rates and a 30% improvement in resource allocation efficiency, all while maintaining the highest standards of data security and compliance.\n\nBrief: BetaHealth Telemedicine Platform on Microsoft Azure Customer Need: With the evolving healthcare landscape, BetaHealth aims to provide remote consultations and care to its patients. They envision a Telemed ...
#  GraphDocument(nodes=[Node(id='Deltaedu', type='Company'), Node(id='Ai-Powered Analytics Platform', type='Technology'), Node(id='Aws', type='Platform'), Node(id='Sagemaker', type='Service'), Node(id='Quicksight', type='Service'), Node(id='Dynamodb', type='Service'), Node(id='Lambda', type='Service'), Node(id='Virtual Classroom Platform', type='Technology'), Node(id='Chime', type='Service'), Node(id='Elastic Beanstalk', type='Service'), Node(id='Rds', type='Service'), Node(id='Epsilonfinance', type='Company'), Node(id='Mobile-First Digital Wallet', type='Technology'), Node(id='Google Cloud', type='Platform')], relationships=[Relationship(source=Node(id='Deltaedu', type='Company'), target=Node(id='Ai-Powered Analytics Platform', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Ai-Powered Analytics Platform', type='Technology'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Sagemaker', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Quicksight', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Dynamodb', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Lambda', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Deltaedu', type='Company'), target=Node(id='Virtual Classroom Platform', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Virtual Classroom Platform', type='Technology'), target=Node(id='Aws', type='Platform'), type='HOSTED_ON'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Chime', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Elastic Beanstalk', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Aws', type='Platform'), target=Node(id='Rds', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Epsilonfinance', type='Company'), target=Node(id='Mobile-First Digital Wallet', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Technology'), target=Node(id='Google Cloud', type='Platform'), type='HOSTED_ON')], source=Document(page_content=" in remote consultations, greatly enhancing patient accessibility.\n\nBrief: DeltaEdu AI-Powered Student Performance Analytics on AWS Customer Need: DeltaEdu wishes to gain deeper insights into student performance, identify learning gaps, and personalize the educational journey. They need an AI-driven analytics solution on AWS to achieve these objectives.\nDelivered Solution: We've introduced an AI-Powered Analytics platform on AWS, which analyzes student interactions, test scores, and feedback. The platform provides educators with insights to tailor teaching methodologies and offer personalized learning paths.\nTechnologies Involved: Our solution integrates AWS services such as SageMaker for machine learning, QuickSight for visualization, DynamoDB for data storage, and Lambda for serverless analytics functions.\nTimeline & Customer Experience: Over a six-month period, the platform was developed and refined in collaboration with DeltaEdu's academic and IT teams. Post-implementation, educators have reported a 25% improvement in identifying and addressing student learning gaps.\n\nBrief: DeltaEdu Virtual Classroom Platform on AWS Customer Need: In the wake of the digital transformation in education, DeltaEdu aims to create an interactive and engaging virtual classroom experience. They are looking for a scalable solution on the AWS platform to conduct online classes and workshops.\nDelivered Solution: We have designed a Virtual Classroom Platform on AWS, allowing DeltaEdu to host live sessions, interactive discussions, and hands-on workshops. With features like real-time quizzes, breakout rooms, and collaborative whiteboards, the platform enriches the ...
#  GraphDocument(nodes=[Node(id='Epsilonfinance', type='Company'), Node(id='Mobile-First Digital Wallet', type='Product'), Node(id='Google Cloud', type='Technology'), Node(id='Firebase', type='Technology'), Node(id='Firestore', type='Technology'), Node(id='Cloud Functions', type='Technology'), Node(id='Google Pay Apis', type='Technology'), Node(id='Gammatech', type='Company'), Node(id='Autonomous Fleet Management System', type='Product'), Node(id='Microsoft Azure', type='Technology'), Node(id='Azure Iot Hub', type='Technology'), Node(id='Azure Functions', type='Technology'), Node(id='Azure Machine Learning', type='Technology'), Node(id='Azure Blob Storage', type='Technology'), Node(id='Azure Logic Apps', type='Technology'), Node(id='Azure Monitor', type='Technology')], relationships=[Relationship(source=Node(id='Epsilonfinance', type='Company'), target=Node(id='Mobile-First Digital Wallet', type='Product'), type='DEVELOPED'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Google Cloud', type='Technology'), type='HOSTED_ON'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Firebase', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Firestore', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Cloud Functions', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Mobile-First Digital Wallet', type='Product'), target=Node(id='Google Pay Apis', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Autonomous Fleet Management System', type='Product'), type='DEVELOPED'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Microsoft Azure', type='Technology'), type='HOSTED_ON'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Iot Hub', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Functions', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Machine Learning', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Blob Storage', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Logic Apps', type='Technology'), type='UTILIZES'), Relationship(source=Node(id='Autonomous Fleet Management System', type='Product'), target=Node(id='Azure Monitor', type='Technology'), type='UTILIZES')], source=Document(page_content="\nDelivered Solution: We've developed a Mobile-First Digital Wallet for EpsilonFinance on Google Cloud. The app supports instant transactions, integrates with various banks, and offers curated deals and loyalty rewards to users.\nTechnologies Involved: The app leverages Google Cloud services such as Firebase for backend operations, Firestore for real-time data storage, Cloud Functions for serverless computing, and Google Pay APIs for payment integrations.\nTimeline & Customer Experience: The project, completed in seven months, saw EpsilonFinance's vision transformed into a market-ready app. Since its release, the app has garnered over 100,000 downloads with a 4.8-star rating on app stores.\nWould you like these briefs saved as individual files, or is there anything else you'd like to adjust?\n\nBrief: GammaTech Autonomous Fleet Management System on Azure\nCustomer Need: GammaTech, a transportation and logistics company, is in search of a state-of-the-art solution to manage their expanding fleet of autonomous vehicles. They require a comprehensive pla ...
#  GraphDocument(nodes=[Node(id='Smart Logistics Platform', type='Platform'), Node(id='Microsoft Azure', type='Technology'), Node(id='Real-Time Vehicle Monitoring', type='Feature'), Node(id='Route Optimization', type='Feature'), Node(id='Safety Enhancement', type='Feature'), Node(id='Efficiency Enhancement', type='Feature'), Node(id='Gammatech', type='Customer'), Node(id='Azure Iot Hub', type='Service'), Node(id='Azure Functions', type='Service'), Node(id='Azure Machine Learning', type='Service'), Node(id='Azure Cosmos Db', type='Service'), Node(id='Azure Devops', type='Service')], relationships=[Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Microsoft Azure', type='Technology'), type='HOSTED_ON'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Real-Time Vehicle Monitoring', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Route Optimization', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Safety Enhancement', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Efficiency Enhancement', type='Feature'), type='OFFERS'), Relationship(source=Node(id='Gammatech', type='Customer'), target=Node(id='Smart Logistics Platform', type='Platform'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Iot Hub', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Functions', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Machine Learning', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Cosmos Db', type='Service'), type='UTILIZES'), Relationship(source=Node(id='Smart Logistics Platform', type='Platform'), target=Node(id='Azure Devops', type='Service'), type='UTILIZES')], source=Document(page_content=" solution to optimize their evolving fleet management needs. They require a comprehensive platform hosted on Microsoft Azure that can provide real-time vehicle monitoring and control, route optimization, and enhance the safety and efficiency of their operations.\nDelivered Solution: We have developed a Smart Logistics Platform hosted on Microsoft Azure, incorporating cutting-edge technologies for real-time logistics management. This platform offers real-time vehicle tracking, route optimization using AI algorithms, and predictive maintenance to reduce downtime. GammaTech now has a centralized system ensuring the safety and efficiency of their logistics operations.\nTechnologies Involved: Our solution utilizes Microsoft Azure services, including Azure IoT Hub for real-time data from vehicles, Azure Functions for event-driven control, and Azure Machine Learning for predictive maintenance and route optimization. Azure Cosmos DB stores real-time data, and Azure DevOps streamlines development and deployment processes.\nTimeline & Customer Experience: The project was successfully delivered within a year, closely collaborating with GammaTech's logistics and fleet management teams. Since implementation, GammaTech has achieved a 20% reduction in fuel consumption, a 15% improvement in delivery times, and a 30% decrease in maintenance costs, establishing themselves as a leader in smart logistics within the industry.", metadata={'source': 'Data/Projects.txt', 'id': 'f110949ccc3594b3d65be20afb3c7592'})),
#  GraphDocument(nodes=[Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Amanda Rodriguez', type='Person'), Node(id='Jason Mitchell', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Betahealth', type='Organization'), Node(id='Alphacorp', type='Organization'), Node(id='Gammatech', type='Organization'), Node(id='Azure', type='Technology'), Node(id='Aws', type='Technology'), Node(id='Ec2', type='Technology'), Node(id='Sagemaker', type='Technology'), Node(id='Iot', type='Technology')], relationships=[Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Betahealth', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Alphacorp', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Amanda Rodriguez', type='Person'), target=Node(id='Betahealth', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Gammatech', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech', type='Organization'), type='WORKED_ON'), Relationship(source=Node(id='Betahealth', type='Organization'), target=Node(id='Azure', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Alphacorp', type='Organization'), target=Node(id='Aws', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Alphacorp', type='Organization'), target=Node(id='Ec2', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Alphacorp', type='Organization'), target=Node(id='Sagemaker', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Gammatech', type='Organization'), target=Node(id='Azure', type='Technology'), type='USES_TECHNOLOGY'), Relationship(source=Node(id='Gammatech', type='Organization'), target=Node(id='Iot', type='Technology'), type='USES_TECHNOLOGY')], source=Document(page_content='\n        "id": "kcojvioa",\n        "type": "message",\n        "user": "Sarah Johnson",\n        "text": "I\'ve been working on BetaHealth\'s Azure-based data analytics platform. It\'s a game-changer for patient care. Collaborating with healthcare professionals has been invaluable."\n    \n    \n        "id": "asjdnifkjasd",\n        "type": "message",\n        "user": "David Patel",\n        "text": "AlphaCorp\'s AWS-powered supply chain optimization project has been both challenging and rewarding. AWS services like EC2 and SageMaker have made a real difference."\n    \n    \n        "id": "asdffjasd",\n        "type": "message",\n        "user": "Amanda Rodriguez",\n        "text": "Data security and compliance have been my top priorities in BetaHealth\'s Azure project. It\'s vital to protect patient information while advancing healthcare."\n    \n    \n        "id": "lklklkhg",\n        "type": "message",\n        "user": "Jason Mitchell",\n        "text": "Working on GammaTech\'s Azure-based smart logistics platform has been fascinating. Real-time logistics management is transforming the transportation industry."\n    \n    \n        "id": "jtthh",\n        "type": "message",\n        "user": "Emily Turner",\n        "text": "The IoT integration in GammaTech\'s Azure project is exciting. Azure technologies have truly revolutionized how we manage logistics operations."\n    \n    \n        "id": "heaas",\n     ', metadata={'source': 'Data/slackmsg.txt', 'id': 'c1fc6e57652bf387c3d6fb982e9d8df3'})),
#  GraphDocument(nodes=[Node(id='Olivia Martinez', type='Person'), Node(id='William Lee', type='Person'), Node(id='Sarah Johnson', type='Person'), Node(id='David Patel', type='Person'), Node(id='Emily Turner', type='Person'), Node(id='Alphacorp', type='Company'), Node(id='Aws', type='Service'), Node(id='Ec2', type='Service'), Node(id='Sagemaker', type='Service'), Node(id='Betahealth', type='Company'), Node(id='Azure', type='Service'), Node(id='Ml', type='Capability'), Node(id='Gammatech', type='Company')], relationships=[Relationship(source=Node(id='Olivia Martinez', type='Person'), target=Node(id='Alphacorp', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='William Lee', type='Person'), target=Node(id='Betahealth', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='Alphacorp', type='Company'), type='WORKED_ON_SAME_PROJECT'), Relationship(source=Node(id='Sarah Johnson', type='Person'), target=Node(id='David Patel', type='Person'), type='ASKED_ABOUT_PROJECT_EXPERIENCE'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Alphacorp', type='Company'), type='SHARED_EXPERIENCE'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Aws', type='Service'), type='EXPERIENCED_BENEFITS'), Relationship(source=Node(id='David Patel', type='Person'), target=Node(id='Supply Chain', type='Domain'), type='IMPROVEMENTS_IN'), Relationship(source=Node(id='Emily Turner', type='Person'), target=Node(id='Gammatech', type='Company'), type='ASKED_ABOUT_PROJECT_EXPERIENCE')], source=Document(page_content='   \n        "id": "heaas",\n        "type": "message",\n        "user": "Olivia Martinez",\n        "text": "Monitoring efficiency improvements in AlphaCorp\'s AWS project is fascinating. AWS services like EC2 and SageMaker are making a real impact."\n    \n    \n        "id": "jsssa",\n        "type": "message",\n        "user": "William Lee",\n        "text": "Applying predictive modeling in BetaHealth\'s Azure project is exciting. Collaborating with healthcare professionals and Azure\'s ML capabilities are key."\n    \n    \n        "id": "ppaa",\n        "type": "message",\n        "user": "Sarah Johnson",\n        "text": "David, I noticed you worked on the AlphaCorp AWS project too. How was your experience with it?"\n    \n    \n        "id": "gfdd",\n        "type": "message",\n        "user": "David Patel",\n        "text": "Sarah, it was quite challenging but rewarding. We\'ve seen significant cost reductions and improved deliveries in their supply chain."\n    \n    \n        "id": "lopyyy",\n        "type": "message",\n        "user": "Emily Turner",\n        "text": "Jason, I\'m curious about your experience with real-time logistics in the GammaTech project. Any key takeaways?"\n    \n    \n        "id": "fgtttta",\n        "type": "message",\n        "user": "Jason Mitchell",\n       ', metadata={'source': 'Data/slackmsg.txt', 'id': '651f3f5e10b88af3078c520b9103bb19'})),
#  GraphDocument(nodes=[Node(id='Jason Mitchell', type='Person'), Node(id='Emily', type='Person'), Node(id='Azure Iot Hub', type='Technology'), Node(id='Functions', type='Technology'), Node(id='Olivia Martinez', type='Person'), Node(id='Michael Clark', type='Person'), Node(id='Alphacorp', type='Company'), Node(id='Aws', type='Technology'), Node(id='Ec2', type='Technology'), Node(id='Sagemaker', type='Technology'), Node(id='Jessica White', type='Person'), Node(id='Betahealth', type='Company'), Node(id='Azure Key Vault', type='Technology'), Node(id='Daniel Brown', type='Person'), Node(id='Gammatech', type='Company')], relationships=[Relationship(source=Node(id='Jason Mitchell', type='Person'), target=Node(id='Emily', type='Person'), type='COLLEAGUE'), Relationship(source=Node(id='Olivia Martinez', type='Person'), target=Node(id='Michael Clark', type='Person'), type='COLLEAGUE'), Relationship(source=Node(id='Michael Clark', type='Person'), target=Node(id='Alphacorp', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Alphacorp', type='Company'), target=Node(id='Aws', type='Technology'), type='USES'), Relationship(source=Node(id='Aws', type='Technology'), target=Node(id='Ec2', type='Technology'), type='DRIVES_COST_REDUCTIONS'), Relationship(source=Node(id='Aws', type='Technology'), target=Node(id='Sagemaker', type='Technology'), type='DRIVES_COST_REDUCTIONS'), Relationship(source=Node(id='Jessica White', type='Person'), target=Node(id='Betahealth', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Betahealth', type='Company'), target=Node(id='Azure Key Vault', type='Technology'), type='IMPLEMENTS'), Relationship(source=Node(id='Daniel Brown', type='Person'), target=Node(id='Gammatech', type='Company'), type='WORKS_ON_PROJECT'), Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Azure Iot Hub', type='Technology'), type='USES'), Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Functions', type='Technology'), type='USES')], source=Document(page_content='",\n        "user": "Jason Mitchell",\n        "text": "Emily, real-time logistics is all about efficiency. Azure IoT Hub and Functions have made our logistics operations highly responsive."\n    \n    \n        "id": "pldfpaks",\n        "type": "message",\n        "user": "Olivia Martinez",\n        "text": "Michael, how\'s the monitoring going in the AlphaCorp AWS project? Any interesting insights you\'ve gained?"\n    \n    \n        "id": "ytthf",\n        "type": "message",\n        "user": "Michael Clark",\n        "text": "The data engineering challenge in AlphaCorp\'s AWS project has been rewarding. AWS services like EC2 and SageMaker have driven cost reductions."\n    \n    \n        "id": "agaer",\n        "type": "message",\n        "user": "Jessica White",\n        "text": "Ensuring data privacy in BetaHealth\'s Azure project is crucial. Collaborating with healthcare professionals and implementing Azure Key Vault is a must."\n    \n    \n        "id": "bbtgg",\n        "type": "message",\n        "user": "Daniel Brown",\n        "text": "Optimizing logistics operations in GammaTech\'s Azure project is a great journey. Azure IoT Hub and Functions are pivotal for efficiency."\n    \n    \n        "id": "gapaa",\n        "type": "message",\n        "user": "Michael Clark",\n        "text": "Olivia, it\'s been fascinating. We\'ve uncovered insights that have led to cost reductions and better on', metadata={'source': 'Data/slackmsg.txt', 'id': 'f368da0b6ecb628b6abee99015eb12c6'})),
#  GraphDocument(nodes=[Node(id='Olivia', type='Person'), Node(id='Emma Martinez', type='Person'), Node(id='Sophia Anderson', type='Person'), Node(id='Ava Jackson', type='Person'), Node(id='Aiden Lewis', type='Person'), Node(id='Lucas Taylor', type='Person'), Node(id='Epsilonfinance', type='Company'), Node(id='Google Pay Apis', type='Technology'), Node(id='Google Cloud', type='Technology'), Node(id='Alphacorp', type='Company'), Node(id='Deltaedu', type='Company'), Node(id='Real-Time Monitoring', type='Concept'), Node(id='Digital Wallet', type='Product'), Node(id='Security Features', type='Concept'), Node(id='Visualization Module', type='Product'), Node(id='Insights', type='Concept'), Node(id='Breakout Rooms', type='Product'), Node(id='Virtual Classroom', type='Product')], relationships=[Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Epsilonfinance', type='Company'), type='HAS_WORKED_IN'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Epsilonfinance', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Epsilonfinance', type='Company'), type='HAS_MENTIONED_SECURITY'), Relationship(source=Node(id='Ava Jackson', type='Person'), target=Node(id='Alphacorp', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Alphacorp', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Lucas Taylor', type='Person'), target=Node(id='Deltaedu', type='Company'), type='HAS_MENTIONED_PRODUCT'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Real-Time Monitoring', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Insights', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Cost Reductions', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Olivia', type='Person'), target=Node(id='Better On-Time Deliveries', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Emma Martinez', type='Person'), target=Node(id='Google Pay Apis', type='Technology'), type='HAS_INTEGRATED_WITH'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Google Cloud', type='Technology'), type='HAS_MENTIONED'), Relationship(source=Node(id='Sophia Anderson', type='Person'), target=Node(id='Security Features', type='Concept'), type='HAS_MENTIONED'), Relationship(source=Node(id='Ava Jackson', type='Person'), target=Node(id='Visualization Module', type='Product'), type='HAS_MENTIONED'), Relationship(source=Node(id='Aiden Lewis', type='Person'), target=Node(id='Visualization Module', type='Product'), type='HAS_MENTIONED'), Relationship(source=Node(id='Lucas Taylor', type='Person'), target=Node(id='Breakout Rooms', type='Product'), type='HAS_MENTIONED'), Relationship(source=Node(id='Lucas Taylor', type='Person'), target=Node(id='Virtual Classroom', type='Product'), type='HAS_MENTIONED')], source=Document(page_content='": "Olivia, it\'s been fascinating. We\'ve uncovered insights that have led to cost reductions and better on-time deliveries. Real-time monitoring is key."\n    \n\n        "id": "6cffae64-d",\n        "type": "message",\n        "user": "Emma Martinez",\n        "text": "EpsilonFinance\'s Digital Wallet is so user-friendly. The integration with Google Pay APIs has made transactions smooth."\n    \n    \n        "id": "c9e872b6-a",\n        "type": "message",\n        "user": "Sophia Anderson",\n        "text": "Securing user data in EpsilonFinance\'s Digital Wallet has been top priority. Google Cloud\'s security features have been instrumental."\n    \n    \n        "id": "944dd6bb-6",\n        "type": "message",\n        "user": "Ava Jackson",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so  ...
#  GraphDocument(nodes=[Node(id='Deltaedu', type='Organization'), Node(id='Virtual Classroom', type='Room')], relationships=[Relationship(source=Node(id='Deltaedu', type='Organization'), target=Node(id='Virtual Classroom', type='Room'), type='HAS')], source=Document(page_content=' rooms in DeltaEdu\'s Virtual Classroom? I\'d love to get feedback."\n    \n    \n        "id": "e756c8ae-c",\n        "type": "message",\n        "user": "Emma Martinez",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so detailed."\n    \n    \n        "id": "6674380b-6",\n        "type": "message",\n        "user": "Ava Jackson",\n        "text": "The personalized learning paths suggested by our AI model for DeltaEdu are spot on. Kudos to the team!"\n    \n    \n        "id": "241c3938-c",\n        "type": "message",\n        "user": "Benjamin White",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so detailed."\n    \n    \n        "id": "877c0c6d-3",\n        "type": "message",\n        "user": "Lucas Taylor",\n        "text": "The remote monitoring in BetaHealth\'s Telemedicine Platform ensures continuous patient care. Azure\'s scalability made it possible."\n    \n\n        "id": "e1bfefde-f",\n        "type": "message",\n        "user": "Ella Smith",\n        "text": "Has anyone tried the breakout rooms in DeltaEdu\'s Virtual Classroom? I\'d love to get feedback."\n    \n    \n        "id": "6ec813a6-0",\n ', metadata={'source': 'Data/slackmsg.txt', 'id': 'd9460e6fc778d3b9a058503379fff284'})),
#  GraphDocument(nodes=[Node(id='Noah Wilson', type='User'), Node(id='Aiden Lewis', type='User'), Node(id='Benjamin White', type='User'), Node(id='Sophia Anderson', type='User'), Node(id='Alphacorp', type='Company'), Node(id='Gammatech', type='Company'), Node(id='Betahealth', type='Company'), Node(id='Epsilonfinance', type='Company'), Node(id='Azure', type='Technology')], relationships=[Relationship(source=Node(id='Noah Wilson', type='User'), target=Node(id='Alphacorp', type='Company'), type='EXPLORED_VISUALIZATION_MODULE'), Relationship(source=Node(id='Aiden Lewis', type='User'), target=Node(id='Gammatech', type='Company'), type='REDUCED_DOWNTIMES'), Relationship(source=Node(id='Benjamin White', type='User'), target=Node(id='Betahealth', type='Company'), type='UTILIZED_REMOTE_MONITORING'), Relationship(source=Node(id='Betahealth', type='Company'), target=Node(id='Azure', type='Technology'), type='UTILIZED_SCALABILITY'), Relationship(source=Node(id='Sophia Anderson', type='User'), target=Node(id='Epsilonfinance', type='Company'), type='TESTED_LOYALTY_REWARDS_FEATURE'), Relationship(source=Node(id='Sophia Anderson', type='User'), target=Node(id='Epsilonfinance', type='Company'), type='TESTED_USER_ENGAGEMENT'), Relationship(source=Node(id='Sophia Anderson', type='User'), target=Node(id='Betahealth', type='Company'), type='EXPERIENCED_PATIENT_DATA_SECURITY_CHALLENGE'), Relationship(source=Node(id='Betahealth', type='Company'), target=Node(id='Azure', type='Technology'), type='UTILIZED_SECURITY_CENTER')], source=Document(page_content=' \n        "id": "6ec813a6-0",\n        "type": "message",\n        "user": "Noah Wilson",\n        "text": "Has anyone checked the new visualization module in AlphaCorp\'s dashboard? The insights are so detailed."\n    \n    \n        "id": "4203972a-d",\n        "type": "message",\n        "user": "Aiden Lewis",\n        "text": "GammaTech\'s Manufacturing Monitoring System has significantly reduced downtimes. Real-time monitoring is the future."\n    \n    \n        "id": "f230a0f7-a",\n        "type": "message",\n        "user": "Benjamin White",\n        "text": "The remote monitoring in BetaHealth\'s Telemedicine Platform ensures continuous patient care. Azure\'s scalability made it possible."\n    \n    \n        "id": "843bab5f-a",\n        "type": "message",\n        "user": "Sophia Anderson",\n        "text": "I\'ve been testing the loyalty rewards feature in EpsilonFinance\'s app. The user engagement is bound to skyrocket!"\n    \n\n        "id": "408133de-0",\n        "type": "message",\n        "user": "Sophia Anderson",\n        "text": "Patient data security in BetaHealth\'s Telemedicine Platform has been a challenge, but Azure Security Center has been a great help."\n    \n    \n        "id": "f17f60cc-0",\n        "type": "message",\n  ', metadata={'source': 'Data/slackmsg.txt', 'id': 'e08d424f05751e0958d34213770c199a'})),
#  GraphDocument(nodes=[Node(id='Gammatech', type='Company'), Node(id='Azure Digital Twins', type='Technology'), Node(id='Deltaedu', type='Company'), Node(id='Aws', type='Technology'), Node(id='Epsilonfinance', type='Company'), Node(id='Google Pay Apis', type='Technology')], relationships=[Relationship(source=Node(id='Gammatech', type='Company'), target=Node(id='Azure Digital Twins', type='Technology'), type='USES'), Relationship(source=Node(id='Deltaedu', type='Company'), target=Node(id='Aws', type='Technology'), type='USES'), Relationship(source=Node(id='Epsilonfinance', type='Company'), target=Node(id='Google Pay Apis', type='Technology'), type='INTEGRATES')], source=Document(page_content='17f60cc-0",\n        "type": "message",\n        "user": "Liam Thompson",\n        "text": "The virtual representation of the manufacturing unit using Azure Digital Twins for GammaTech is fascinating. It\'s like having a digital twin of the entire facility."\n    \n    \n        "id": "01e37dce-1",\n        "type": "message",\n        "user": "Lucas Taylor",\n        "text": "The Virtual Classroom Platform for DeltaEdu on AWS is shaping up really well. The real-time quizzes feature is a hit!"\n    \n    \n        "id": "158f781f-8",\n        "type": "message",\n        "user": "Emma Martinez",\n        "text": "GammaTech\'s Manufacturing Monitoring System has significantly reduced downtimes. Real-time monitoring is the future."\n    \n    \n        "id": "afc5f40e-b",\n        "type": "message",\n        "user": "Isabella Harris",\n        "text": "EpsilonFinance\'s Digital Wallet is so user-friendly. The integration with Google Pay APIs has made transactions smooth."\n    \n    \n        "id": "a00bdb25-0",\n        "type": "message",\n        "user": "Ella Smith",\n        "text": "The virtual representation of the manufacturing unit using Azure Digital Twins for GammaTech is fascinating. It\'s like having a digital twin of the entire facility."\n    \n\n', metadata={'source': 'Data/slackmsg.txt', 'id': '1da2e92358a6aff3b4674f4452fe6f4b'}))]

# %%
# Load environment variables
load_dotenv()

import os

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Next, we need to define Neo4j credentials

NEO4J_USER = os.getenv("NEO4J_USER")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_CONNECTION_URL = os.getenv("NEO4J_CONNECTION_URL")
graph = Neo4jGraph(
    url=os.environ["NEO4J_CONNECTION_URL"], username=os.environ["NEO4J_USER"], password=os.environ["NEO4J_PASSWORD"]
)

# %%
# # Prompt for processing project
# project_template = """
# From the Project Brief below, extract the following Entities & relationships described in the mentioned format 
# 0. ALWAYS FINISH THE OUTPUT. Never send partial responses
# 1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
#    `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. Document must be summarized and stored inside Project entity under `summary` property. You will have to generate as many entities as needed as per the types below:
#     nodes Types:
#     label:'Project',id:string,name:string;summary:string //Project mentioned in the brief; `id` property is the full name of the project, in lowercase, with no capital letters, special characters, spaces or hyphens; Contents of original document must be summarized inside 'summary' property
#     label:'Technology',id:string,name:string //Technology Entity; `id` property is the name of the technology, in camel-case. Identify as many of the technologies used as possible
#     label:'Client',id:string,name:string;industry:string //Client that the project was done for; `id` property is the name of the Client, in camel-case; 'industry' is the industry that the client operates in, as mentioned in the project brief.
    
# 2. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
#     Relationship types:
#     project|USES_TECH|technology 
#     project|HAS_CLIENT|client


# 3. The output should look like :

#     "nodes": ["label":"Project","id":string,"name":string,"summary":string],
#     "relationships": ["projectid|USES_TECH|technologyid"]

# Schema:
# {schema}

# QUESTION: {question}

# YOUR ANSWER:""" 


# # Prompt for processing' profiles
# profile_template = """From the list of people below, extract the following Entities & relationships described in the mentioned format 
# 0. ALWAYS FINISH THE OUTPUT. Never send partial responses
# 1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
#    `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. You will have to generate as many entities as needed as per the types below:
#     nodes Entity Types:
#     label:'Person',id:string,name:string //Person that the data is about. `id` property is the name of the person, in camel-case. 'name' is the person's name, as spelled in the text.
#     label:'Project',id:string,name:string;summary:string //Project mentioned in the profile; `id` property is the full lowercase name of the project, with no capital letters, special characters, spaces or hyphens.
#     label:'Technology',id:string,name:string //Technology Entity, as listed in the "skills"-section of every person; `id` property is the name of the technology, in camel-case.
    
# 3. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
#     Relationship types:
#     person|HAS_SKILLS|technology 
#     project|HAS_PEOPLE|person


# The output should look like :

#     "nodes": ["label":"Person","id":string,"name":string],
#     "relationships": ["projectid|HAS_PEOPLE|personid"]

# # Schema:
# {schema}



# QUESTION: {question}

# YOUR ANSWER:""" 


# # Prompt for processing slack messages

# # slackmsg_template = """
# From the list of messages below, extract the following Entities & relationships described in the mentioned format 
# 0. ALWAYS FINISH THE OUTPUT. Never send partial responses
# 1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
#    `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. You will have to generate as many entities as needed as per the types below:
#     nodes Types:
#     label:'Person',id:string,name:string //Person that sent the message. `id` property is the name of the person, in camel-case; for example, "michaelClark", or "emmaMartinez"; 'name' is the person's name, as spelled in the text.
#     label:'SlackMessage',id:string,text:string //The Slack-Message that was sent; 'id' property should be the message id, as spelled in the reference. 'text' property is the text content of the message, as spelled in the reference
    
# 3. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
#     Relationship types:
#     personid|SENT|slackmessageid

# The output should look like :

#     "nodes": ["label":"SlackMessage","id":string,"text":string],
#     "relationships": ["personid|SENT|messageid"]

# Schema:
# {schema}

# QUESTION: {question}

# YOUR ANSWER:"""

# %%
# combined_template = f"{project_template}\n{profile_template}"

# %% [markdown]
# Cypher generation prompt

# %%
cypher_generation_template = """
You are a helpful IT-project and account management expert who extracts information from documents, 
Use only Nodes and relationships mentioned in the schema, 
Please generate a Cypher query to extract the required information from the graph database.
schema: {schema}

Examples:
Question: Which client's projects use most of our people?
Answer: ```MATCH (c:CLIENT)<-[:HAS_CLIENT]-(p:Project)-[:HAS_PEOPLE]->(person:Person)
RETURN c.name AS Client, COUNT(DISTINCT person) AS NumberOfPeople
ORDER BY NumberOfPeople DESC```
Question: Which person uses the largest number of different technologies?
Answer: ```MATCH (person:Person)-[:USES_TECH]->(tech:Technology)
RETURN person.name AS PersonName, COUNT(DISTINCT tech) AS NumberOfTechnologies
ORDER BY NumberOfTechnologies DESC```

Question: {question}
"""

# %%
CYPHER_GENERATION_PROMPT = PromptTemplate(
    input_variables=["schema","question"], template=cypher_generation_template
)

# %%
chain = GraphCypherQAChain.from_llm(
    ChatOpenAI(temperature=0, model='gpt-3.5-turbo'), graph=graph, verbose=True,
    cypher_prompt=CYPHER_GENERATION_PROMPT
)

# %%
chain.invoke({"query": "Which person uses the largest number of different technologies?"})
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (person:Person)-[:HAS_SKILL]->(tech:Technology)
# RETURN person.id AS PersonID, COUNT(DISTINCT tech) AS NumberOfTechnologies
# ORDER BY NumberOfTechnologies DESC
# Full Context:
# [{'PersonID': 'Sarah Johnson', 'NumberOfTechnologies': 4}, {'PersonID': 'David Patel', 'NumberOfTechnologies': 4}, {'PersonID': 'Jason Mitchell', 'NumberOfTechnologies': 4}, {'PersonID': 'Sophia Anderson', 'NumberOfTechnologies': 4}, {'PersonID': 'Lucas Taylor', 'NumberOfTechnologies': 4}, {'PersonID': 'Ella Smith', 'NumberOfTechnologies': 4}, {'PersonID': 'Emily Turner', 'NumberOfTechnologies': 3}, {'PersonID': 'Olivia Martinez', 'NumberOfTechnologies': 3}, {'PersonID': 'William Lee', 'NumberOfTechnologies': 3}, {'PersonID': 'Michael Clark', 'NumberOfTechnologies': 3}]
#
# > Finished chain.
# {'query': 'Which person uses the largest number of different technologies?',
#  'result': 'Sarah Johnson, David Patel, Jason Mitchell, Sophia Anderson, Lucas Taylor, and Ella Smith use the largest number of different technologies, each with 4 technologies.'}

# %%
chain.invoke({"query": "Which client's projects use most of our people?"})
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (c:Client)<-[:CLIENT]-(p:Project)-[:HAS_PEOPLE]->(person:Person)
# RETURN c.name AS Client, COUNT(DISTINCT person) AS NumberOfPeople
# ORDER BY NumberOfPeople DESC
# Full Context:
# []
#
# > Finished chain.
# {'query': "Which client's projects use most of our people?",
#  'result': "I don't know the answer."}
